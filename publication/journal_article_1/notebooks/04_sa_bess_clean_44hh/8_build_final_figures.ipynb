# %% [markdown]
# # Build Final Figures (Section 04)
#
# ## Purpose
# Rebuilds final SA BESS combined paper-facing figures from existing outputs only.
#
# ## Run Flow
# 1. Resolve project paths and import the shared build helper.
# 2. Validate required inputs.
# 3. Rebuild canonical Section 04 figures.
# 4. Validate expected Section 04 artifacts.
#
# ## Expected Section 04 Outputs
# - `results/04_sa_bess_clean_44hh/figures/fig20_sa_bess_composition_timeseries_error_combined.png`
# - `results/04_sa_bess_clean_44hh/figures/fig21_sa_bess_hourly_load_ramp_combined.png`
# - `results/04_sa_bess_clean_44hh/figures/fig22_sa_bess_pv_battery_distribution_combined.png`
# - `results/paper_artifact_output_check.csv` (validation report)
#
# ## Notes
# This notebook does not rerun model training; it rebuilds publication artifacts only.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = next((p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'publication' / 'journal_article_1').exists()), None)
if PROJECT_ROOT is None:
    raise RuntimeError('Could not resolve project root from current working directory.')

SCRIPTS_DIR = PROJECT_ROOT / 'publication' / 'journal_article_1' / 'scripts'
if str(SCRIPTS_DIR) not in sys.path:
    sys.path.insert(0, str(SCRIPTS_DIR))

import notebook_artifact_build as nab

# %%
section = '04'
print('=== Section 04: build figures ===')
expected = nab.list_expected_artifacts(section)
print(f'Expected canonical artifacts in section {section}: {len(expected)}')
for p in expected:
    print(' -', p)

nab.ensure_required_inputs()
outputs = nab.build_section_04()
print(f'Generated outputs: {len(outputs)}')
for p in outputs:
    print('generated', p)
# Out:
# === Section 04: build figures ===
# Expected canonical artifacts in section 04: 3
#  - results/04_sa_bess_clean_44hh/figures/fig20_sa_bess_composition_timeseries_error_combined.png
#  - results/04_sa_bess_clean_44hh/figures/fig21_sa_bess_hourly_load_ramp_combined.png
#  - results/04_sa_bess_clean_44hh/figures/fig22_sa_bess_pv_battery_distribution_combined.png
# Generated outputs: 3
# generated C:\Users\z5404477\Documents\PyNNLF\publication\journal_article_1\results\04_sa_bess_clean_44hh\figures\fig20_sa_bess_composition_timeseries_error_combined.png
# generated C:\Users\z5404477\Documents\PyNNLF\publication\journal_article_1\results\04_sa_bess_clean_44hh\figures\fig21_sa_bess_hourly_load_ramp_combined.png
# generated C:\Users\z5404477\Documents\PyNNLF\publication\journal_article_1\results\04_sa_bess_clean_44hh\figures\fig22_sa_bess_pv_battery_distribution_combined.png

# %%
print('=== Section 04: validation ===')
check = nab.check_artifacts('04')
display(check)

exists_count = int(check['exists'].sum())
missing_count = len(check) - exists_count
print(f'Validation summary: {exists_count}/{len(check)} artifacts exist; missing={missing_count}')

if missing_count:
    print('Missing artifacts:')
    for p in check.loc[~check['exists'], 'path']:
        print(' -', p)

nab.assert_artifacts('04')
print('Section 04 artifact check passed.')
# Out:
# === Section 04: validation ===
#                                                 path  exists  size_bytes
# 0  results/04_sa_bess_clean_44hh/figures/fig20_sa...    True     1077010
# 1  results/04_sa_bess_clean_44hh/figures/fig21_sa...    True     1219717
# 2  results/04_sa_bess_clean_44hh/figures/fig22_sa...    True      613374
# Validation summary: 3/3 artifacts exist; missing=0
# Section 04 artifact check passed.

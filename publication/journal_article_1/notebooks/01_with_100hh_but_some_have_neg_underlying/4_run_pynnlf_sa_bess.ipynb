# %% [markdown]
# # 4. Run PyNNLF SA BESS Experiments
#
# This notebook is the manual launch point for the SA BESS PyNNLF experiment. It does not run automatically when opened. Run the cells when you are ready to start or resume the long model batch.

# %% [markdown]
# ## 1. Setup
#
# Resolve the publication project and the local PyNNLF source tree. The local `src` path is inserted before importing PyNNLF so the notebook uses this repository version, not an older installed package.

# %%
from pathlib import Path
import sys

def find_publication_project(start: Path) -> Path:
    for candidate in [start, *start.parents]:
        if (candidate / 'scripts' / 'run_sa_bess_batch.py').exists() and (candidate / 'specs' / 'sa_bess_batch.yaml').exists():
            return candidate
    raise FileNotFoundError('Could not find publication/journal_article_1 from the current working directory.')

def find_repo_root(start: Path) -> Path:
    for candidate in [start, *start.parents]:
        if (candidate / 'pyproject.toml').exists() and (candidate / 'src' / 'pynnlf').exists():
            return candidate
    raise FileNotFoundError('Could not find the PyNNLF repo root.')

PROJECT_DIR = find_publication_project(Path.cwd().resolve())
REPO_ROOT = find_repo_root(PROJECT_DIR)
sys.path.insert(0, str(REPO_ROOT / 'src'))
sys.path.insert(0, str(PROJECT_DIR / 'scripts'))

print(f'Publication project: {PROJECT_DIR}')
print(f'PyNNLF repo root: {REPO_ROOT}')
# Out:
# Publication project: C:\Users\z5404477\Documents\PyNNLF\publication\journal_article_1
# PyNNLF repo root: C:\Users\z5404477\Documents\PyNNLF

# %% [markdown]
# ## 2. Validate Input Datasets
#
# Confirm the three SA BESS datasets are ready for PyNNLF. These checks are quick and do not train any models.

# %%
import pandas as pd

dataset_files = [
    'ds16_sa_bess_underlying_load_30min.csv',
    'ds17_sa_bess_net_load_with_pv_30min.csv',
    'ds18_sa_bess_net_load_with_pv_battery_30min.csv',
]

for filename in dataset_files:
    path = PROJECT_DIR / 'data' / filename
    df = pd.read_csv(path, parse_dates=['datetime'])
    assert list(df.columns) == ['datetime', 'netload_kW'], filename
    assert len(df) == 17_520, filename
    assert df.isna().sum().sum() == 0, filename
    assert df['datetime'].diff().dropna().nunique() == 1, filename
    assert df['datetime'].diff().dropna().iloc[0] == pd.Timedelta(minutes=30), filename
    print(f'{filename}: OK | {df.datetime.min()} to {df.datetime.max()} | rows={len(df):,}')
# Out:
# ds16_sa_bess_underlying_load_30min.csv: OK | 2024-02-26 00:00:00 to 2025-02-24 23:30:00 | rows=17,520
# ds17_sa_bess_net_load_with_pv_30min.csv: OK | 2024-02-26 00:00:00 to 2025-02-24 23:30:00 | rows=17,520
# ds18_sa_bess_net_load_with_pv_battery_30min.csv: OK | 2024-02-26 00:00:00 to 2025-02-24 23:30:00 | rows=17,520

# %% [markdown]
# ## 3. Run Or Resume The Full Batch
#
# This is the long-running step. The runner is resumable: completed dataset/model/hyperparameter combinations are skipped on later runs. Plots are disabled by the runner to keep output size down.

# %%
from run_sa_bess_batch import main as run_sa_bess_batch

run_sa_bess_batch()
# Out:
# [skip 1/36] ds16 m17 hp1
# [skip 2/36] ds16 m8 hp1
# [skip 3/36] ds16 m6 hp1
# [skip 4/36] ds16 m10 hp1
# [skip 5/36] ds16 m7 hp1
# [skip 6/36] ds16 m1 hp1
# [skip 7/36] ds16 m3 hp1
# [skip 8/36] ds16 m9 hp3
# [run 9/36] ds16 m13 hp2
# Pass Test 1 - Forecast horizon is >= dataset frequency
# Pass Test 2 - Hyperparameter choice is possible given the forecast horizon
# Processing CV 1 / 10....
# Epoch [1/100]
# Epoch [1/100] and batch [1/3]
# Epoch [1/100] and batch [2/3]
# Epoch [1/100] and batch [3/3]
# Epoch [1/100], Loss: 3080390.2500, time taken: 8.59 seconds
# Epoch [2/100]
# Epoch [2/100] and batch [1/3]
# Epoch [2/100] and batch [2/3]
# Epoch [2/100] and batch [3/3]
# Epoch [2/100], Loss: 2852560.7500, time taken: 8.73 seconds
# Epoch [3/100]
# Epoch [3/100] and batch [1/3]
# Epoch [3/100] and batch [2/3]
# Epoch [3/100] and batch [3/3]
# Epoch [3/100], Loss: 2635199.0000, time taken: 8.12 seconds
# Epoch [4/100]
# Epoch [4/100] and batch [1/3]
# Epoch [4/100] and batch [2/3]
# Epoch [4/100] and batch [3/3]
# Epoch [4/100], Loss: 2433459.0000, time taken: 6.14 seconds
# Epoch [5/100]
# Epoch [5/100] and batch [1/3]
# Epoch [5/100] and batch [2/3]
# Epoch [5/100] and batch [3/3]
# Epoch [5/100], Loss: 2235697.0000, time taken: 7.88 seconds
# Epoch [6/100]
# Epoch [6/100] and batch [1/3]
# Epoch [6/100] and batch [2/3]
# Epoch [6/100] and batch [3/3]
# Epoch [6/100], Loss: 2045831.6250, time taken: 14.30 seconds
# Epoch [7/100]
# Epoch [7/100] and batch [1/3]
# Epoch [7/100] and batch [2/3]
# Epoch [7/100] and batch [3/3]
# Epoch [7/100], Loss: 1871314.1250, time taken: 9.09 seconds
# Epoch [8/100]
# Epoch [8/100] and batch [1/3]
# Epoch [8/100] and batch [2/3]
# Epoch [8/100] and batch [3/3]
# Epoch [8/100], Loss: 1702006.2500, time taken: 6.92 seconds
# Epoch [9/100]
# Epoch [9/100] and batch [1/3]
# Epoch [9/100] and batch [2/3]
# Epoch [9/100] and batch [3/3]
# Epoch [9/100], Loss: 1544459.8750, time taken: 7.27 seconds
# Epoch [10/100]
# Epoch [10/100] and batch [1/3]
# Epoch [10/100] and batch [2/3]
# Epoch [10/100] and batch [3/3]
# Epoch [10/100], Loss: 1402311.8750, time taken: 7.67 seconds
# Epoch [11/100]
# Epoch [11/100] and batch [1/3]
# Epoch [11/100] and batch [2/3]
# Epoch [11/100] and batch [3/3]
# Epoch [11/100], Loss: 1264310.7500, time taken: 8.13 seconds
# Epoch [12/100]
# Epoch [12/100] and batch [1/3]
# Epoch [12/100] and batch [2/3]
# Epoch [12/100] and batch [3/3]
# Epoch [12/100], Loss: 1141885.7500, time taken: 9.48 seconds
# Epoch [13/100]
# Epoch [13/100] and batch [1/3]
# Epoch [13/100] and batch [2/3]
# Epoch [13/100] and batch [3/3]
# Epoch [13/100], Loss: 1023645.6250, time taken: 9.73 seconds
# Epoch [14/100]
# Epoch [14/100] and batch [1/3]
# Epoch [14/100] and batch [2/3]
# Epoch [14/100] and batch [3/3]
# Epoch [14/100], Loss: 917588.5000, time taken: 10.01 seconds
# Epoch [15/100]
# Epoch [15/100] and batch [1/3]
# Epoch [15/100] and batch [2/3]
# Epoch [15/100] and batch [3/3]
# Epoch [15/100], Loss: 818184.4375, time taken: 9.69 seconds
# Epoch [16/100]
# Epoch [16/100] and batch [1/3]
# Epoch [16/100] and batch [2/3]
# Epoch [16/100] and batch [3/3]
# Epoch [16/100], Loss: 727555.0000, time taken: 10.01 seconds
# Epoch [17/100]
# Epoch [17/100] and batch [1/3]
# Epoch [17/100] and batch [2/3]
# Epoch [17/100] and batch [3/3]
# Epoch [17/100], Loss: 644761.6875, time taken: 9.89 seconds
# Epoch [18/100]
# Epoch [18/100] and batch [1/3]
# Epoch [18/100] and batch [2/3]
# Epoch [18/100] and batch [3/3]
# Epoch [18/100], Loss: 573385.1250, time taken: 8.93 seconds
# Epoch [19/100]
# Epoch [19/100] and batch [1/3]
# Epoch [19/100] and batch [2/3]
# Epoch [19/100] and batch [3/3]
# Epoch [19/100], Loss: 504967.5312, time taken: 8.72 seconds
# Epoch [20/100]
# Epoch [20/100] and batch [1/3]
# Epoch [20/100] and batch [2/3]
# Epoch [20/100] and batch [3/3]
# Epoch [20/100], Loss: 443699.2812, time taken: 9.23 seconds
# Epoch [21/100]
# Epoch [21/100] and batch [1/3]
# Epoch [21/100] and batch [2/3]
# Epoch [21/100] and batch [3/3]
# Epoch [21/100], Loss: 387701.1562, time taken: 9.82 seconds
# Epoch [22/100]
# Epoch [22/100] and batch [1/3]
# Epoch [22/100] and batch [2/3]
# Epoch [22/100] and batch [3/3]
# Epoch [22/100], Loss: 339506.7500, time taken: 9.22 seconds
# Epoch [23/100]
# Epoch [23/100] and batch [1/3]
# Epoch [23/100] and batch [2/3]
# Epoch [23/100] and batch [3/3]
# Epoch [23/100], Loss: 295117.6250, time taken: 8.70 seconds
# Epoch [24/100]
# Epoch [24/100] and batch [1/3]
# Epoch [24/100] and batch [2/3]
# Epoch [24/100] and batch [3/3]
# Epoch [24/100], Loss: 255845.2969, time taken: 9.40 seconds
# Epoch [25/100]
# Epoch [25/100] and batch [1/3]
# Epoch [25/100] and batch [2/3]
# Epoch [25/100] and batch [3/3]
# Epoch [25/100], Loss: 221017.2812, time taken: 9.32 seconds
# Epoch [26/100]
# Epoch [26/100] and batch [1/3]
# Epoch [26/100] and batch [2/3]
# Epoch [26/100] and batch [3/3]
# Epoch [26/100], Loss: 191587.5156, time taken: 9.91 seconds
# Epoch [27/100]
# Epoch [27/100] and batch [1/3]
# Epoch [27/100] and batch [2/3]
# Epoch [27/100] and batch [3/3]
# Epoch [27/100], Loss: 165301.8438, time taken: 10.62 seconds
# Epoch [28/100]
# Epoch [28/100] and batch [1/3]
# Epoch [28/100] and batch [2/3]
# Epoch [28/100] and batch [3/3]
# Epoch [28/100], Loss: 141362.9688, time taken: 10.05 seconds
# Epoch [29/100]
# Epoch [29/100] and batch [1/3]
# Epoch [29/100] and batch [2/3]
# Epoch [29/100] and batch [3/3]
# Epoch [29/100], Loss: 120193.5078, time taken: 10.05 seconds
# Epoch [30/100]
# Epoch [30/100] and batch [1/3]
# Epoch [30/100] and batch [2/3]
# Epoch [30/100] and batch [3/3]
# Epoch [30/100], Loss: 103259.0234, time taken: 10.07 seconds
# Epoch [31/100]
# Epoch [31/100] and batch [1/3]
# Epoch [31/100] and batch [2/3]
# Epoch [31/100] and batch [3/3]
# Epoch [31/100], Loss: 88017.3516, time taken: 11.01 seconds
# Epoch [32/100]
# Epoch [32/100] and batch [1/3]
# Epoch [32/100] and batch [2/3]
# Epoch [32/100] and batch [3/3]
# Epoch [32/100], Loss: 73154.4531, time taken: 12.32 seconds
# Epoch [33/100]
# Epoch [33/100] and batch [1/3]
# Epoch [33/100] and batch [2/3]
# Epoch [33/100] and batch [3/3]
# Epoch [33/100], Loss: 62559.4766, time taken: 11.60 seconds
# Epoch [34/100]
# Epoch [34/100] and batch [1/3]
# Epoch [34/100] and batch [2/3]
# Epoch [34/100] and batch [3/3]
# Epoch [34/100], Loss: 53675.5039, time taken: 11.00 seconds
# Epoch [35/100]
# Epoch [35/100] and batch [1/3]
# Epoch [35/100] and batch [2/3]
# Epoch [35/100] and batch [3/3]
# Epoch [35/100], Loss: 44314.7734, time taken: 11.27 seconds
# Epoch [36/100]
# Epoch [36/100] and batch [1/3]
# Epoch [36/100] and batch [2/3]
# Epoch [36/100] and batch [3/3]
# Epoch [36/100], Loss: 37297.5039, time taken: 11.06 seconds
# Epoch [37/100]
# Epoch [37/100] and batch [1/3]
# Epoch [37/100] and batch [2/3]
# Epoch [37/100] and batch [3/3]
# Epoch [37/100], Loss: 31533.2207, time taken: 11.10 seconds
# Epoch [38/100]
# Epoch [38/100] and batch [1/3]
# Epoch [38/100] and batch [2/3]
# Epoch [38/100] and batch [3/3]
# Epoch [38/100], Loss: 26340.9004, time taken: 11.53 seconds
# Epoch [39/100]
# Epoch [39/100] and batch [1/3]
# Epoch [39/100] and batch [2/3]
# Epoch [39/100] and batch [3/3]
# Epoch [39/100], Loss: 22277.0410, time taken: 11.54 seconds
# Epoch [40/100]
# Epoch [40/100] and batch [1/3]
# Epoch [40/100] and batch [2/3]
# Epoch [40/100] and batch [3/3]
# Epoch [40/100], Loss: 18652.3730, time taken: 11.48 seconds
# Epoch [41/100]
# Epoch [41/100] and batch [1/3]
# Epoch [41/100] and batch [2/3]
# Epoch [41/100] and batch [3/3]
# Epoch [41/100], Loss: 15565.3027, time taken: 11.31 seconds
# Epoch [42/100]
# Epoch [42/100] and batch [1/3]
# Epoch [42/100] and batch [2/3]
# Epoch [42/100] and batch [3/3]
# Epoch [42/100], Loss: 13195.1689, time taken: 10.98 seconds
# Epoch [43/100]
# Epoch [43/100] and batch [1/3]
# Epoch [43/100] and batch [2/3]
# Epoch [43/100] and batch [3/3]
# Epoch [43/100], Loss: 11262.5459, time taken: 11.70 seconds
# Epoch [44/100]
# Epoch [44/100] and batch [1/3]
# Epoch [44/100] and batch [2/3]
# Epoch [44/100] and batch [3/3]
# Epoch [44/100], Loss: 10013.3252, time taken: 11.53 seconds
# Epoch [45/100]
# Epoch [45/100] and batch [1/3]
# Epoch [45/100] and batch [2/3]
# Epoch [45/100] and batch [3/3]
# Epoch [45/100], Loss: 8128.2788, time taken: 11.70 seconds
# Epoch [46/100]
# Epoch [46/100] and batch [1/3]
# Epoch [46/100] and batch [2/3]
# Epoch [46/100] and batch [3/3]
# Epoch [46/100], Loss: 7397.9375, time taken: 11.70 seconds
# Epoch [47/100]
# Epoch [47/100] and batch [1/3]
# Epoch [47/100] and batch [2/3]
# Epoch [47/100] and batch [3/3]
# Epoch [47/100], Loss: 6413.3882, time taken: 11.85 seconds
# Epoch [48/100]
# Epoch [48/100] and batch [1/3]
# Epoch [48/100] and batch [2/3]
# Epoch [48/100] and batch [3/3]
# Epoch [48/100], Loss: 5717.5151, time taken: 11.82 seconds
# Epoch [49/100]
# Epoch [49/100] and batch [1/3]
# Epoch [49/100] and batch [2/3]
# Epoch [49/100] and batch [3/3]
# Epoch [49/100], Loss: 5306.4761, time taken: 10.91 seconds
# Epoch [50/100]
# Epoch [50/100] and batch [1/3]
# Epoch [50/100] and batch [2/3]
# Epoch [50/100] and batch [3/3]
# Epoch [50/100], Loss: 4895.5400, time taken: 11.94 seconds
# Epoch [51/100]
# Epoch [51/100] and batch [1/3]
# Epoch [51/100] and batch [2/3]
# Epoch [51/100] and batch [3/3]
# Epoch [51/100], Loss: 4451.8833, time taken: 15.91 seconds
# Epoch [52/100]
# Epoch [52/100] and batch [1/3]
# Epoch [52/100] and batch [2/3]
# Epoch [52/100] and batch [3/3]
# Epoch [52/100], Loss: 4207.3579, time taken: 17.31 seconds
# Epoch [53/100]
# Epoch [53/100] and batch [1/3]
# Epoch [53/100] and batch [2/3]
# Epoch [53/100] and batch [3/3]
# Epoch [53/100], Loss: 4181.4258, time taken: 15.84 seconds
# Epoch [54/100]
# Epoch [54/100] and batch [1/3]
# Epoch [54/100] and batch [2/3]
# Epoch [54/100] and batch [3/3]
# Epoch [54/100], Loss: 3923.3838, time taken: 13.80 seconds
# Epoch [55/100]
# Epoch [55/100] and batch [1/3]
# Epoch [55/100] and batch [2/3]
# Epoch [55/100] and batch [3/3]
# Epoch [55/100], Loss: 3816.6455, time taken: 14.29 seconds
# Epoch [56/100]
# Epoch [56/100] and batch [1/3]
# Epoch [56/100] and batch [2/3]
# Epoch [56/100] and batch [3/3]
# Epoch [56/100], Loss: 3709.4692, time taken: 11.34 seconds
# Epoch [57/100]
# Epoch [57/100] and batch [1/3]
# Epoch [57/100] and batch [2/3]
# Epoch [57/100] and batch [3/3]
# Epoch [57/100], Loss: 3612.8557, time taken: 10.25 seconds
# Epoch [58/100]
# Epoch [58/100] and batch [1/3]
# Epoch [58/100] and batch [2/3]
# Epoch [58/100] and batch [3/3]
# Epoch [58/100], Loss: 3657.3281, time taken: 8.27 seconds
# Epoch [59/100]
# Epoch [59/100] and batch [1/3]
# Epoch [59/100] and batch [2/3]
# Epoch [59/100] and batch [3/3]
# Epoch [59/100], Loss: 3487.8184, time taken: 8.13 seconds
# Epoch [60/100]
# Epoch [60/100] and batch [1/3]
# Epoch [60/100] and batch [2/3]
# Epoch [60/100] and batch [3/3]
# Epoch [60/100], Loss: 3499.4233, time taken: 8.76 seconds
# Epoch [61/100]
# Epoch [61/100] and batch [1/3]
# Epoch [61/100] and batch [2/3]
# Epoch [61/100] and batch [3/3]
# Epoch [61/100], Loss: 3455.8914, time taken: 9.64 seconds
# Epoch [62/100]
# Epoch [62/100] and batch [1/3]
# Epoch [62/100] and batch [2/3]
# Epoch [62/100] and batch [3/3]
# Epoch [62/100], Loss: 3531.7354, time taken: 9.40 seconds
# Epoch [63/100]
# Epoch [63/100] and batch [1/3]
# Epoch [63/100] and batch [2/3]
# Epoch [63/100] and batch [3/3]
# Epoch [63/100], Loss: 3467.2876, time taken: 8.63 seconds
# Epoch [64/100]
# Epoch [64/100] and batch [1/3]
# Epoch [64/100] and batch [2/3]
# Epoch [64/100] and batch [3/3]
# Epoch [64/100], Loss: 3523.5356, time taken: 8.72 seconds
# Epoch [65/100]
# Epoch [65/100] and batch [1/3]
# Epoch [65/100] and batch [2/3]
# Epoch [65/100] and batch [3/3]
# Epoch [65/100], Loss: 3585.8271, time taken: 8.82 seconds
# Epoch [66/100]
# Epoch [66/100] and batch [1/3]
# Epoch [66/100] and batch [2/3]
# Epoch [66/100] and batch [3/3]
# Epoch [66/100], Loss: 3457.1045, time taken: 8.29 seconds
# Epoch [67/100]
# Epoch [67/100] and batch [1/3]
# Epoch [67/100] and batch [2/3]
# Epoch [67/100] and batch [3/3]
# Epoch [67/100], Loss: 3490.3010, time taken: 12.48 seconds
# Epoch [68/100]
# Epoch [68/100] and batch [1/3]
# Epoch [68/100] and batch [2/3]
# Epoch [68/100] and batch [3/3]
# Epoch [68/100], Loss: 3561.5237, time taken: 15.37 seconds
# Epoch [69/100]
# Epoch [69/100] and batch [1/3]
# Epoch [69/100] and batch [2/3]
# Epoch [69/100] and batch [3/3]
# Epoch [69/100], Loss: 3409.2566, time taken: 13.63 seconds
# Epoch [70/100]
# Epoch [70/100] and batch [1/3]
# Epoch [70/100] and batch [2/3]
# Epoch [70/100] and batch [3/3]
# Epoch [70/100], Loss: 3474.3962, time taken: 12.37 seconds
# Epoch [71/100]
# Epoch [71/100] and batch [1/3]
# Epoch [71/100] and batch [2/3]
# Epoch [71/100] and batch [3/3]
# Epoch [71/100], Loss: 3512.0066, time taken: 11.25 seconds
# Epoch [72/100]
# Epoch [72/100] and batch [1/3]
# Epoch [72/100] and batch [2/3]
# Epoch [72/100] and batch [3/3]
# Epoch [72/100], Loss: 3565.5369, time taken: 11.80 seconds
# Epoch [73/100]
# Epoch [73/100] and batch [1/3]
# Epoch [73/100] and batch [2/3]
# Epoch [73/100] and batch [3/3]
# Epoch [73/100], Loss: 3472.3604, time taken: 12.08 seconds
# Epoch [74/100]
# Epoch [74/100] and batch [1/3]
# Epoch [74/100] and batch [2/3]
# Epoch [74/100] and batch [3/3]
# Epoch [74/100], Loss: 3451.5718, time taken: 11.62 seconds
# Epoch [75/100]
# Epoch [75/100] and batch [1/3]
# Epoch [75/100] and batch [2/3]
# Epoch [75/100] and batch [3/3]
# Epoch [75/100], Loss: 3432.2798, time taken: 9.49 seconds
# Epoch [76/100]
# Epoch [76/100] and batch [1/3]
# Epoch [76/100] and batch [2/3]
# Epoch [76/100] and batch [3/3]
# Epoch [76/100], Loss: 3530.8145, time taken: 7.90 seconds
# Epoch [77/100]
# Epoch [77/100] and batch [1/3]
# Epoch [77/100] and batch [2/3]
# Epoch [77/100] and batch [3/3]
# Epoch [77/100], Loss: 3426.5681, time taken: 8.38 seconds
# Epoch [78/100]
# Epoch [78/100] and batch [1/3]
# Epoch [78/100] and batch [2/3]
# Epoch [78/100] and batch [3/3]
# Epoch [78/100], Loss: 3478.4299, time taken: 8.00 seconds
# Epoch [79/100]
# Epoch [79/100] and batch [1/3]
# Epoch [79/100] and batch [2/3]
# Epoch [79/100] and batch [3/3]
# Epoch [79/100], Loss: 3493.1409, time taken: 7.92 seconds
# Epoch [80/100]
# Epoch [80/100] and batch [1/3]
# Epoch [80/100] and batch [2/3]
# Epoch [80/100] and batch [3/3]
# Epoch [80/100], Loss: 3434.2781, time taken: 9.07 seconds
# Epoch [81/100]
# Epoch [81/100] and batch [1/3]
# Epoch [81/100] and batch [2/3]
# Epoch [81/100] and batch [3/3]
# Epoch [81/100], Loss: 3482.6777, time taken: 9.45 seconds
# Epoch [82/100]
# Epoch [82/100] and batch [1/3]
# Epoch [82/100] and batch [2/3]
# Epoch [82/100] and batch [3/3]
# Epoch [82/100], Loss: 3441.1450, time taken: 14.34 seconds
# Epoch [83/100]
# Epoch [83/100] and batch [1/3]
# Epoch [83/100] and batch [2/3]
# Epoch [83/100] and batch [3/3]
# Epoch [83/100], Loss: 3380.6829, time taken: 22.81 seconds
# Epoch [84/100]
# Epoch [84/100] and batch [1/3]
# Epoch [84/100] and batch [2/3]
# Epoch [84/100] and batch [3/3]
# Epoch [84/100], Loss: 3471.7122, time taken: 17.75 seconds
# Epoch [85/100]
# Epoch [85/100] and batch [1/3]
# Epoch [85/100] and batch [2/3]
# Epoch [85/100] and batch [3/3]
# Epoch [85/100], Loss: 3471.0317, time taken: 16.23 seconds
# Epoch [86/100]
# Epoch [86/100] and batch [1/3]
# Epoch [86/100] and batch [2/3]
# Epoch [86/100] and batch [3/3]
# Epoch [86/100], Loss: 3413.3569, time taken: 15.24 seconds
# Epoch [87/100]
# Epoch [87/100] and batch [1/3]
# Epoch [87/100] and batch [2/3]
# Epoch [87/100] and batch [3/3]
# Epoch [87/100], Loss: 3484.0095, time taken: 15.32 seconds
# Epoch [88/100]
# Epoch [88/100] and batch [1/3]
# Epoch [88/100] and batch [2/3]
# Epoch [88/100] and batch [3/3]
# Epoch [88/100], Loss: 3513.1709, time taken: 15.15 seconds
# Epoch [89/100]
# Epoch [89/100] and batch [1/3]
# Epoch [89/100] and batch [2/3]
# Epoch [89/100] and batch [3/3]
# Epoch [89/100], Loss: 3521.3179, time taken: 16.08 seconds
# Epoch [90/100]
# Epoch [90/100] and batch [1/3]
# Epoch [90/100] and batch [2/3]
# Epoch [90/100] and batch [3/3]
# Epoch [90/100], Loss: 3574.3630, time taken: 15.13 seconds
# Epoch [91/100]
# Epoch [91/100] and batch [1/3]
# Epoch [91/100] and batch [2/3]
# Epoch [91/100] and batch [3/3]
# Epoch [91/100], Loss: 3475.9780, time taken: 14.63 seconds
# Epoch [92/100]
# Epoch [92/100] and batch [1/3]
# Epoch [92/100] and batch [2/3]
# Epoch [92/100] and batch [3/3]
# Epoch [92/100], Loss: 3456.7808, time taken: 15.94 seconds
# Epoch [93/100]
# Epoch [93/100] and batch [1/3]
# Epoch [93/100] and batch [2/3]
# Epoch [93/100] and batch [3/3]
# Epoch [93/100], Loss: 3426.7180, time taken: 15.33 seconds
# Epoch [94/100]
# Epoch [94/100] and batch [1/3]
# Epoch [94/100] and batch [2/3]
# Epoch [94/100] and batch [3/3]
# Epoch [94/100], Loss: 3383.5991, time taken: 14.53 seconds
# Epoch [95/100]
# Epoch [95/100] and batch [1/3]
# Epoch [95/100] and batch [2/3]
# Epoch [95/100] and batch [3/3]
# Epoch [95/100], Loss: 3520.3611, time taken: 14.75 seconds
# Epoch [96/100]
# Epoch [96/100] and batch [1/3]
# Epoch [96/100] and batch [2/3]
# Epoch [96/100] and batch [3/3]
# Epoch [96/100], Loss: 3441.5698, time taken: 14.73 seconds
# Epoch [97/100]
# Epoch [97/100] and batch [1/3]
# Epoch [97/100] and batch [2/3]
# Epoch [97/100] and batch [3/3]
# Epoch [97/100], Loss: 3529.8884, time taken: 14.69 seconds
# Epoch [98/100]
# Epoch [98/100] and batch [1/3]
# Epoch [98/100] and batch [2/3]
# Epoch [98/100] and batch [3/3]
# Epoch [98/100], Loss: 3444.0684, time taken: 14.12 seconds
# Epoch [99/100]
# Epoch [99/100] and batch [1/3]
# Epoch [99/100] and batch [2/3]
# Epoch [99/100] and batch [3/3]
# Epoch [99/100], Loss: 3464.0139, time taken: 13.99 seconds
# Epoch [100/100]
# Epoch [100/100] and batch [1/3]
# Epoch [100/100] and batch [2/3]
# Epoch [100/100] and batch [3/3]
# Epoch [100/100], Loss: 3456.3062, time taken: 14.23 seconds
#
# Processing CV 2 / 10....
# Epoch [1/100]
# Epoch [1/100] and batch [1/3]
# Epoch [1/100] and batch [2/3]
# Epoch [1/100] and batch [3/3]
# Epoch [1/100], Loss: 3087245.7500, time taken: 11.83 seconds
# Epoch [2/100]
# Epoch [2/100] and batch [1/3]
# Epoch [2/100] and batch [2/3]
# Epoch [2/100] and batch [3/3]
# Epoch [2/100], Loss: 2859595.2500, time taken: 11.25 seconds
# Epoch [3/100]
# Epoch [3/100] and batch [1/3]
# Epoch [3/100] and batch [2/3]
# Epoch [3/100] and batch [3/3]
# Epoch [3/100], Loss: 2641404.7500, time taken: 11.71 seconds
# Epoch [4/100]
# Epoch [4/100] and batch [1/3]
# Epoch [4/100] and batch [2/3]
# Epoch [4/100] and batch [3/3]
# Epoch [4/100], Loss: 2439552.0000, time taken: 11.95 seconds
# Epoch [5/100]
# Epoch [5/100] and batch [1/3]
# Epoch [5/100] and batch [2/3]
# Epoch [5/100] and batch [3/3]
# Epoch [5/100], Loss: 2241464.7500, time taken: 12.32 seconds
# Epoch [6/100]
# Epoch [6/100] and batch [1/3]
# Epoch [6/100] and batch [2/3]
# Epoch [6/100] and batch [3/3]
# Epoch [6/100], Loss: 2051440.3750, time taken: 12.15 seconds
# Epoch [7/100]
# Epoch [7/100] and batch [1/3]
# Epoch [7/100] and batch [2/3]
# Epoch [7/100] and batch [3/3]
# Epoch [7/100], Loss: 1876923.8750, time taken: 11.69 seconds
# Epoch [8/100]
# Epoch [8/100] and batch [1/3]
# Epoch [8/100] and batch [2/3]
# Epoch [8/100] and batch [3/3]
# Epoch [8/100], Loss: 1707889.7500, time taken: 11.81 seconds
# Epoch [9/100]
# Epoch [9/100] and batch [1/3]
# Epoch [9/100] and batch [2/3]
# Epoch [9/100] and batch [3/3]
# Epoch [9/100], Loss: 1549825.0000, time taken: 11.97 seconds
# Epoch [10/100]
# Epoch [10/100] and batch [1/3]
# Epoch [10/100] and batch [2/3]
# Epoch [10/100] and batch [3/3]
# Epoch [10/100], Loss: 1407687.8750, time taken: 11.92 seconds
# Epoch [11/100]
# Epoch [11/100] and batch [1/3]
# Epoch [11/100] and batch [2/3]
# Epoch [11/100] and batch [3/3]
# Epoch [11/100], Loss: 1268158.7500, time taken: 12.78 seconds
# Epoch [12/100]
# Epoch [12/100] and batch [1/3]
# Epoch [12/100] and batch [2/3]
# Epoch [12/100] and batch [3/3]
# Epoch [12/100], Loss: 1146352.0000, time taken: 11.87 seconds
# Epoch [13/100]
# Epoch [13/100] and batch [1/3]
# Epoch [13/100] and batch [2/3]
# Epoch [13/100] and batch [3/3]
# Epoch [13/100], Loss: 1028030.4375, time taken: 12.37 seconds
# Epoch [14/100]
# Epoch [14/100] and batch [1/3]
# Epoch [14/100] and batch [2/3]
# Epoch [14/100] and batch [3/3]
# Epoch [14/100], Loss: 920565.6250, time taken: 12.73 seconds
# Epoch [15/100]
# Epoch [15/100] and batch [1/3]
# Epoch [15/100] and batch [2/3]
# Epoch [15/100] and batch [3/3]
# Epoch [15/100], Loss: 822003.2500, time taken: 12.55 seconds
# Epoch [16/100]
# Epoch [16/100] and batch [1/3]
# Epoch [16/100] and batch [2/3]
# Epoch [16/100] and batch [3/3]
# Epoch [16/100], Loss: 730102.4375, time taken: 12.77 seconds
# Epoch [17/100]
# Epoch [17/100] and batch [1/3]
# Epoch [17/100] and batch [2/3]
# Epoch [17/100] and batch [3/3]
# Epoch [17/100], Loss: 647799.0625, time taken: 11.81 seconds
# Epoch [18/100]
# Epoch [18/100] and batch [1/3]
# Epoch [18/100] and batch [2/3]
# Epoch [18/100] and batch [3/3]
# Epoch [18/100], Loss: 576151.4375, time taken: 12.21 seconds
# Epoch [19/100]
# Epoch [19/100] and batch [1/3]
# Epoch [19/100] and batch [2/3]
# Epoch [19/100] and batch [3/3]
# Epoch [19/100], Loss: 507870.2188, time taken: 11.99 seconds
# Epoch [20/100]
# Epoch [20/100] and batch [1/3]
# Epoch [20/100] and batch [2/3]
# Epoch [20/100] and batch [3/3]
# Epoch [20/100], Loss: 445996.4062, time taken: 12.73 seconds
# Epoch [21/100]
# Epoch [21/100] and batch [1/3]
# Epoch [21/100] and batch [2/3]
# Epoch [21/100] and batch [3/3]
# Epoch [21/100], Loss: 389863.3750, time taken: 12.49 seconds
# Epoch [22/100]
# Epoch [22/100] and batch [1/3]
# Epoch [22/100] and batch [2/3]
# Epoch [22/100] and batch [3/3]
# Epoch [22/100], Loss: 341302.9375, time taken: 12.59 seconds
# Epoch [23/100]
# Epoch [23/100] and batch [1/3]
# Epoch [23/100] and batch [2/3]
# Epoch [23/100] and batch [3/3]
# Epoch [23/100], Loss: 296990.7188, time taken: 13.25 seconds
# Epoch [24/100]
# Epoch [24/100] and batch [1/3]
# Epoch [24/100] and batch [2/3]
# Epoch [24/100] and batch [3/3]
# Epoch [24/100], Loss: 257155.5781, time taken: 14.31 seconds
# Epoch [25/100]
# Epoch [25/100] and batch [1/3]
# Epoch [25/100] and batch [2/3]
# Epoch [25/100] and batch [3/3]
# Epoch [25/100], Loss: 222504.8125, time taken: 13.71 seconds
# Epoch [26/100]
# Epoch [26/100] and batch [1/3]
# Epoch [26/100] and batch [2/3]
# Epoch [26/100] and batch [3/3]
# Epoch [26/100], Loss: 192657.1562, time taken: 13.96 seconds
# Epoch [27/100]
# Epoch [27/100] and batch [1/3]
# Epoch [27/100] and batch [2/3]
# Epoch [27/100] and batch [3/3]
# Epoch [27/100], Loss: 166628.6562, time taken: 13.44 seconds
# Epoch [28/100]
# Epoch [28/100] and batch [1/3]
# Epoch [28/100] and batch [2/3]
# Epoch [28/100] and batch [3/3]
# Epoch [28/100], Loss: 142413.9688, time taken: 13.66 seconds
# Epoch [29/100]
# Epoch [29/100] and batch [1/3]
# Epoch [29/100] and batch [2/3]
# Epoch [29/100] and batch [3/3]
# Epoch [29/100], Loss: 121140.8516, time taken: 14.09 seconds
# Epoch [30/100]
# Epoch [30/100] and batch [1/3]
# Epoch [30/100] and batch [2/3]
# Epoch [30/100] and batch [3/3]
# Epoch [30/100], Loss: 104337.9688, time taken: 15.35 seconds
# Epoch [31/100]
# Epoch [31/100] and batch [1/3]
# Epoch [31/100] and batch [2/3]
# Epoch [31/100] and batch [3/3]
# Epoch [31/100], Loss: 88769.7109, time taken: 14.37 seconds
# Epoch [32/100]
# Epoch [32/100] and batch [1/3]
# Epoch [32/100] and batch [2/3]
# Epoch [32/100] and batch [3/3]
# Epoch [32/100], Loss: 73941.7578, time taken: 14.40 seconds
# Epoch [33/100]
# Epoch [33/100] and batch [1/3]
# Epoch [33/100] and batch [2/3]
# Epoch [33/100] and batch [3/3]
# Epoch [33/100], Loss: 63120.9688, time taken: 14.71 seconds
# Epoch [34/100]
# Epoch [34/100] and batch [1/3]
# Epoch [34/100] and batch [2/3]
# Epoch [34/100] and batch [3/3]
# Epoch [34/100], Loss: 54204.7891, time taken: 14.69 seconds
# Epoch [35/100]
# Epoch [35/100] and batch [1/3]
# Epoch [35/100] and batch [2/3]
# Epoch [35/100] and batch [3/3]
# Epoch [35/100], Loss: 44785.2227, time taken: 14.39 seconds
# Epoch [36/100]
# Epoch [36/100] and batch [1/3]
# Epoch [36/100] and batch [2/3]
# Epoch [36/100] and batch [3/3]
# Epoch [36/100], Loss: 37791.9414, time taken: 14.80 seconds
# Epoch [37/100]
# Epoch [37/100] and batch [1/3]
# Epoch [37/100] and batch [2/3]
# Epoch [37/100] and batch [3/3]
# Epoch [37/100], Loss: 31919.2988, time taken: 14.73 seconds
# Epoch [38/100]
# Epoch [38/100] and batch [1/3]
# Epoch [38/100] and batch [2/3]
# Epoch [38/100] and batch [3/3]
# Epoch [38/100], Loss: 26665.7812, time taken: 14.53 seconds
# Epoch [39/100]
# Epoch [39/100] and batch [1/3]
# Epoch [39/100] and batch [2/3]
# Epoch [39/100] and batch [3/3]
# Epoch [39/100], Loss: 22569.0117, time taken: 14.52 seconds
# Epoch [40/100]
# Epoch [40/100] and batch [1/3]
# Epoch [40/100] and batch [2/3]
# Epoch [40/100] and batch [3/3]
# Epoch [40/100], Loss: 18969.8379, time taken: 15.07 seconds
# Epoch [41/100]
# Epoch [41/100] and batch [1/3]
# Epoch [41/100] and batch [2/3]
# Epoch [41/100] and batch [3/3]
# Epoch [41/100], Loss: 15811.8848, time taken: 14.82 seconds
# Epoch [42/100]
# Epoch [42/100] and batch [1/3]
# Epoch [42/100] and batch [2/3]
# Epoch [42/100] and batch [3/3]
# Epoch [42/100], Loss: 13436.3271, time taken: 15.06 seconds
# Epoch [43/100]
# Epoch [43/100] and batch [1/3]
# Epoch [43/100] and batch [2/3]
# Epoch [43/100] and batch [3/3]
# Epoch [43/100], Loss: 11411.5303, time taken: 15.69 seconds
# Epoch [44/100]
# Epoch [44/100] and batch [1/3]
# Epoch [44/100] and batch [2/3]
# Epoch [44/100] and batch [3/3]
# Epoch [44/100], Loss: 10144.5674, time taken: 14.82 seconds
# Epoch [45/100]
# Epoch [45/100] and batch [1/3]
# Epoch [45/100] and batch [2/3]
# Epoch [45/100] and batch [3/3]
# Epoch [45/100], Loss: 8270.4229, time taken: 15.85 seconds
# Epoch [46/100]
# Epoch [46/100] and batch [1/3]
# Epoch [46/100] and batch [2/3]
# Epoch [46/100] and batch [3/3]
# Epoch [46/100], Loss: 7532.9307, time taken: 15.72 seconds
# Epoch [47/100]
# Epoch [47/100] and batch [1/3]
# Epoch [47/100] and batch [2/3]
# Epoch [47/100] and batch [3/3]
# Epoch [47/100], Loss: 6594.5771, time taken: 14.83 seconds
# Epoch [48/100]
# Epoch [48/100] and batch [1/3]
# Epoch [48/100] and batch [2/3]
# Epoch [48/100] and batch [3/3]
# Epoch [48/100], Loss: 5841.2896, time taken: 14.67 seconds
# Epoch [49/100]
# Epoch [49/100] and batch [1/3]
# Epoch [49/100] and batch [2/3]
# Epoch [49/100] and batch [3/3]
# Epoch [49/100], Loss: 5415.5605, time taken: 15.93 seconds
# Epoch [50/100]
# Epoch [50/100] and batch [1/3]
# Epoch [50/100] and batch [2/3]
# Epoch [50/100] and batch [3/3]
# Epoch [50/100], Loss: 5048.8237, time taken: 15.38 seconds
# Epoch [51/100]
# Epoch [51/100] and batch [1/3]
# Epoch [51/100] and batch [2/3]
# Epoch [51/100] and batch [3/3]
# Epoch [51/100], Loss: 4562.8110, time taken: 15.71 seconds
# Epoch [52/100]
# Epoch [52/100] and batch [1/3]
# Epoch [52/100] and batch [2/3]
# Epoch [52/100] and batch [3/3]
# Epoch [52/100], Loss: 4368.2803, time taken: 15.78 seconds
# Epoch [53/100]
# Epoch [53/100] and batch [1/3]
# Epoch [53/100] and batch [2/3]
# Epoch [53/100] and batch [3/3]
# Epoch [53/100], Loss: 4232.7827, time taken: 15.41 seconds
# Epoch [54/100]
# Epoch [54/100] and batch [1/3]
# Epoch [54/100] and batch [2/3]
# Epoch [54/100] and batch [3/3]
# Epoch [54/100], Loss: 4025.2856, time taken: 15.25 seconds
# Epoch [55/100]
# Epoch [55/100] and batch [1/3]
# Epoch [55/100] and batch [2/3]
# Epoch [55/100] and batch [3/3]
# Epoch [55/100], Loss: 3938.5671, time taken: 16.20 seconds
# Epoch [56/100]
# Epoch [56/100] and batch [1/3]
# Epoch [56/100] and batch [2/3]
# Epoch [56/100] and batch [3/3]
# Epoch [56/100], Loss: 3731.6948, time taken: 15.21 seconds
# Epoch [57/100]
# Epoch [57/100] and batch [1/3]
# Epoch [57/100] and batch [2/3]
# Epoch [57/100] and batch [3/3]
# Epoch [57/100], Loss: 3711.2607, time taken: 16.28 seconds
# Epoch [58/100]
# Epoch [58/100] and batch [1/3]
# Epoch [58/100] and batch [2/3]
# Epoch [58/100] and batch [3/3]
# Epoch [58/100], Loss: 3710.3225, time taken: 15.50 seconds
# Epoch [59/100]
# Epoch [59/100] and batch [1/3]
# Epoch [59/100] and batch [2/3]
# Epoch [59/100] and batch [3/3]
# Epoch [59/100], Loss: 3551.9163, time taken: 15.25 seconds
# Epoch [60/100]
# Epoch [60/100] and batch [1/3]
# Epoch [60/100] and batch [2/3]
# Epoch [60/100] and batch [3/3]
# Epoch [60/100], Loss: 3594.7046, time taken: 15.50 seconds
# Epoch [61/100]
# Epoch [61/100] and batch [1/3]
# Epoch [61/100] and batch [2/3]
# Epoch [61/100] and batch [3/3]
# Epoch [61/100], Loss: 3568.3972, time taken: 15.43 seconds
# Epoch [62/100]
# Epoch [62/100] and batch [1/3]
# Epoch [62/100] and batch [2/3]
# Epoch [62/100] and batch [3/3]
# Epoch [62/100], Loss: 3610.7188, time taken: 15.43 seconds
# Epoch [63/100]
# Epoch [63/100] and batch [1/3]
# Epoch [63/100] and batch [2/3]
# Epoch [63/100] and batch [3/3]
# Epoch [63/100], Loss: 3557.1494, time taken: 15.61 seconds
# Epoch [64/100]
# Epoch [64/100] and batch [1/3]
# Epoch [64/100] and batch [2/3]
# Epoch [64/100] and batch [3/3]
# Epoch [64/100], Loss: 3625.9329, time taken: 15.32 seconds
# Epoch [65/100]
# Epoch [65/100] and batch [1/3]
# Epoch [65/100] and batch [2/3]
# Epoch [65/100] and batch [3/3]
# Epoch [65/100], Loss: 3631.2305, time taken: 16.29 seconds
# Epoch [66/100]
# Epoch [66/100] and batch [1/3]
# Epoch [66/100] and batch [2/3]
# Epoch [66/100] and batch [3/3]
# Epoch [66/100], Loss: 3529.9988, time taken: 15.06 seconds
# Epoch [67/100]
# Epoch [67/100] and batch [1/3]
# Epoch [67/100] and batch [2/3]
# Epoch [67/100] and batch [3/3]
# Epoch [67/100], Loss: 3555.2627, time taken: 17.31 seconds
# Epoch [68/100]
# Epoch [68/100] and batch [1/3]
# Epoch [68/100] and batch [2/3]
# Epoch [68/100] and batch [3/3]
# Epoch [68/100], Loss: 3642.4126, time taken: 16.29 seconds
# Epoch [69/100]
# Epoch [69/100] and batch [1/3]
# Epoch [69/100] and batch [2/3]
# Epoch [69/100] and batch [3/3]
# Epoch [69/100], Loss: 3473.2595, time taken: 15.08 seconds
# Epoch [70/100]
# Epoch [70/100] and batch [1/3]
# Epoch [70/100] and batch [2/3]
# Epoch [70/100] and batch [3/3]
# Epoch [70/100], Loss: 3597.7039, time taken: 15.58 seconds
# Epoch [71/100]
# Epoch [71/100] and batch [1/3]
# Epoch [71/100] and batch [2/3]
# Epoch [71/100] and batch [3/3]
# Epoch [71/100], Loss: 3595.6807, time taken: 16.18 seconds
# Epoch [72/100]
# Epoch [72/100] and batch [1/3]
# Epoch [72/100] and batch [2/3]
# Epoch [72/100] and batch [3/3]
# Epoch [72/100], Loss: 3645.0999, time taken: 15.81 seconds
# Epoch [73/100]
# Epoch [73/100] and batch [1/3]
# Epoch [73/100] and batch [2/3]
# Epoch [73/100] and batch [3/3]
# Epoch [73/100], Loss: 3540.5996, time taken: 15.42 seconds
# Epoch [74/100]
# Epoch [74/100] and batch [1/3]
# Epoch [74/100] and batch [2/3]
# Epoch [74/100] and batch [3/3]
# Epoch [74/100], Loss: 3572.9258, time taken: 15.19 seconds
# Epoch [75/100]
# Epoch [75/100] and batch [1/3]
# Epoch [75/100] and batch [2/3]
# Epoch [75/100] and batch [3/3]
# Epoch [75/100], Loss: 3509.8054, time taken: 15.08 seconds
# Epoch [76/100]
# Epoch [76/100] and batch [1/3]
# Epoch [76/100] and batch [2/3]
# Epoch [76/100] and batch [3/3]
# Epoch [76/100], Loss: 3620.1838, time taken: 18.25 seconds
# Epoch [77/100]
# Epoch [77/100] and batch [1/3]
# Epoch [77/100] and batch [2/3]
# Epoch [77/100] and batch [3/3]
# Epoch [77/100], Loss: 3476.4016, time taken: 15.88 seconds
# Epoch [78/100]
# Epoch [78/100] and batch [1/3]
# Epoch [78/100] and batch [2/3]
# Epoch [78/100] and batch [3/3]
# Epoch [78/100], Loss: 3568.0200, time taken: 15.99 seconds
# Epoch [79/100]
# Epoch [79/100] and batch [1/3]
# Epoch [79/100] and batch [2/3]
# Epoch [79/100] and batch [3/3]
# Epoch [79/100], Loss: 3578.9810, time taken: 15.10 seconds
# Epoch [80/100]
# Epoch [80/100] and batch [1/3]
# Epoch [80/100] and batch [2/3]
# Epoch [80/100] and batch [3/3]
# Epoch [80/100], Loss: 3542.3267, time taken: 14.62 seconds
# Epoch [81/100]
# Epoch [81/100] and batch [1/3]
# Epoch [81/100] and batch [2/3]
# Epoch [81/100] and batch [3/3]
# Epoch [81/100], Loss: 3595.5796, time taken: 14.58 seconds
# Epoch [82/100]
# Epoch [82/100] and batch [1/3]
# Epoch [82/100] and batch [2/3]
# Epoch [82/100] and batch [3/3]
# Epoch [82/100], Loss: 3499.2695, time taken: 15.22 seconds
# Epoch [83/100]
# Epoch [83/100] and batch [1/3]
# Epoch [83/100] and batch [2/3]
# Epoch [83/100] and batch [3/3]
# Epoch [83/100], Loss: 3470.3894, time taken: 15.16 seconds
# Epoch [84/100]
# Epoch [84/100] and batch [1/3]
# Epoch [84/100] and batch [2/3]
# Epoch [84/100] and batch [3/3]
# Epoch [84/100], Loss: 3531.0093, time taken: 15.85 seconds
# Epoch [85/100]
# Epoch [85/100] and batch [1/3]
# Epoch [85/100] and batch [2/3]
# Epoch [85/100] and batch [3/3]
# Epoch [85/100], Loss: 3574.3528, time taken: 14.32 seconds
# Epoch [86/100]
# Epoch [86/100] and batch [1/3]
# Epoch [86/100] and batch [2/3]
# Epoch [86/100] and batch [3/3]
# Epoch [86/100], Loss: 3488.8474, time taken: 15.53 seconds
# Epoch [87/100]
# Epoch [87/100] and batch [1/3]
# Epoch [87/100] and batch [2/3]
# Epoch [87/100] and batch [3/3]
# Epoch [87/100], Loss: 3558.4539, time taken: 15.20 seconds
# Epoch [88/100]
# Epoch [88/100] and batch [1/3]
# Epoch [88/100] and batch [2/3]
# Epoch [88/100] and batch [3/3]
# Epoch [88/100], Loss: 3587.1257, time taken: 15.18 seconds
# Epoch [89/100]
# Epoch [89/100] and batch [1/3]
# Epoch [89/100] and batch [2/3]
# Epoch [89/100] and batch [3/3]
# Epoch [89/100], Loss: 3593.4810, time taken: 14.88 seconds
# Epoch [90/100]
# Epoch [90/100] and batch [1/3]
# Epoch [90/100] and batch [2/3]
# Epoch [90/100] and batch [3/3]
# Epoch [90/100], Loss: 3664.3491, time taken: 14.75 seconds
# Epoch [91/100]
# Epoch [91/100] and batch [1/3]
# Epoch [91/100] and batch [2/3]
# Epoch [91/100] and batch [3/3]
# Epoch [91/100], Loss: 3562.1804, time taken: 14.94 seconds
# Epoch [92/100]
# Epoch [92/100] and batch [1/3]
# Epoch [92/100] and batch [2/3]
# Epoch [92/100] and batch [3/3]
# Epoch [92/100], Loss: 3525.2749, time taken: 14.65 seconds
# Epoch [93/100]
# Epoch [93/100] and batch [1/3]
# Epoch [93/100] and batch [2/3]
# Epoch [93/100] and batch [3/3]
# Epoch [93/100], Loss: 3526.0784, time taken: 14.60 seconds
# Epoch [94/100]
# Epoch [94/100] and batch [1/3]
# Epoch [94/100] and batch [2/3]
# Epoch [94/100] and batch [3/3]
# Epoch [94/100], Loss: 3465.9912, time taken: 14.68 seconds
# Epoch [95/100]
# Epoch [95/100] and batch [1/3]
# Epoch [95/100] and batch [2/3]
# Epoch [95/100] and batch [3/3]
# Epoch [95/100], Loss: 3594.7900, time taken: 15.34 seconds
# Epoch [96/100]
# Epoch [96/100] and batch [1/3]
# Epoch [96/100] and batch [2/3]
# Epoch [96/100] and batch [3/3]
# Epoch [96/100], Loss: 3488.4016, time taken: 15.34 seconds
# Epoch [97/100]
# Epoch [97/100] and batch [1/3]
# Epoch [97/100] and batch [2/3]
# Epoch [97/100] and batch [3/3]
# Epoch [97/100], Loss: 3603.2913, time taken: 15.30 seconds
# Epoch [98/100]
# Epoch [98/100] and batch [1/3]
# Epoch [98/100] and batch [2/3]
# Epoch [98/100] and batch [3/3]
# Epoch [98/100], Loss: 3529.1050, time taken: 14.07 seconds
# Epoch [99/100]
# Epoch [99/100] and batch [1/3]
# Epoch [99/100] and batch [2/3]
# Epoch [99/100] and batch [3/3]
# Epoch [99/100], Loss: 3566.8865, time taken: 13.98 seconds
# Epoch [100/100]
# Epoch [100/100] and batch [1/3]
# Epoch [100/100] and batch [2/3]
# Epoch [100/100] and batch [3/3]
# Epoch [100/100], Loss: 3505.5691, time taken: 14.24 seconds
#
# Processing CV 3 / 10....
# Epoch [1/100]
# Epoch [1/100] and batch [1/3]
# Epoch [1/100] and batch [2/3]
# Epoch [1/100] and batch [3/3]
# Epoch [1/100], Loss: 3087594.7500, time taken: 11.67 seconds
# Epoch [2/100]
# Epoch [2/100] and batch [1/3]
# Epoch [2/100] and batch [2/3]
# Epoch [2/100] and batch [3/3]
# Epoch [2/100], Loss: 2859289.2500, time taken: 11.58 seconds
# Epoch [3/100]
# Epoch [3/100] and batch [1/3]
# Epoch [3/100] and batch [2/3]
# Epoch [3/100] and batch [3/3]
# Epoch [3/100], Loss: 2641012.5000, time taken: 11.77 seconds
# Epoch [4/100]
# Epoch [4/100] and batch [1/3]
# Epoch [4/100] and batch [2/3]
# Epoch [4/100] and batch [3/3]
# Epoch [4/100], Loss: 2439523.5000, time taken: 12.14 seconds
# Epoch [5/100]
# Epoch [5/100] and batch [1/3]
# Epoch [5/100] and batch [2/3]
# Epoch [5/100] and batch [3/3]
# Epoch [5/100], Loss: 2240706.0000, time taken: 12.38 seconds
# Epoch [6/100]
# Epoch [6/100] and batch [1/3]
# Epoch [6/100] and batch [2/3]
# Epoch [6/100] and batch [3/3]
# Epoch [6/100], Loss: 2051435.1250, time taken: 12.93 seconds
# Epoch [7/100]
# Epoch [7/100] and batch [1/3]
# Epoch [7/100] and batch [2/3]
# Epoch [7/100] and batch [3/3]
# Epoch [7/100], Loss: 1876599.5000, time taken: 11.95 seconds
# Epoch [8/100]
# Epoch [8/100] and batch [1/3]
# Epoch [8/100] and batch [2/3]
# Epoch [8/100] and batch [3/3]
# Epoch [8/100], Loss: 1707480.1250, time taken: 12.14 seconds
# Epoch [9/100]
# Epoch [9/100] and batch [1/3]
# Epoch [9/100] and batch [2/3]
# Epoch [9/100] and batch [3/3]
# Epoch [9/100], Loss: 1549741.8750, time taken: 11.82 seconds
# Epoch [10/100]
# Epoch [10/100] and batch [1/3]
# Epoch [10/100] and batch [2/3]
# Epoch [10/100] and batch [3/3]
# Epoch [10/100], Loss: 1407418.0000, time taken: 11.75 seconds
# Epoch [11/100]
# Epoch [11/100] and batch [1/3]
# Epoch [11/100] and batch [2/3]
# Epoch [11/100] and batch [3/3]
# Epoch [11/100], Loss: 1267860.7500, time taken: 12.00 seconds
# Epoch [12/100]
# Epoch [12/100] and batch [1/3]
# Epoch [12/100] and batch [2/3]
# Epoch [12/100] and batch [3/3]
# Epoch [12/100], Loss: 1146373.6250, time taken: 12.04 seconds
# Epoch [13/100]
# Epoch [13/100] and batch [1/3]
# Epoch [13/100] and batch [2/3]
# Epoch [13/100] and batch [3/3]
# Epoch [13/100], Loss: 1027515.5625, time taken: 13.04 seconds
# Epoch [14/100]
# Epoch [14/100] and batch [1/3]
# Epoch [14/100] and batch [2/3]
# Epoch [14/100] and batch [3/3]
# Epoch [14/100], Loss: 920038.5000, time taken: 12.87 seconds
# Epoch [15/100]
# Epoch [15/100] and batch [1/3]
# Epoch [15/100] and batch [2/3]
# Epoch [15/100] and batch [3/3]
# Epoch [15/100], Loss: 821946.3125, time taken: 13.04 seconds
# Epoch [16/100]
# Epoch [16/100] and batch [1/3]
# Epoch [16/100] and batch [2/3]
# Epoch [16/100] and batch [3/3]
# Epoch [16/100], Loss: 729763.8750, time taken: 12.49 seconds
# Epoch [17/100]
# Epoch [17/100] and batch [1/3]
# Epoch [17/100] and batch [2/3]
# Epoch [17/100] and batch [3/3]
# Epoch [17/100], Loss: 647392.1875, time taken: 12.04 seconds
# Epoch [18/100]
# Epoch [18/100] and batch [1/3]
# Epoch [18/100] and batch [2/3]
# Epoch [18/100] and batch [3/3]
# Epoch [18/100], Loss: 575836.5625, time taken: 11.85 seconds
# Epoch [19/100]
# Epoch [19/100] and batch [1/3]
# Epoch [19/100] and batch [2/3]
# Epoch [19/100] and batch [3/3]
# Epoch [19/100], Loss: 507352.8438, time taken: 12.40 seconds
# Epoch [20/100]
# Epoch [20/100] and batch [1/3]
# Epoch [20/100] and batch [2/3]
# Epoch [20/100] and batch [3/3]
# Epoch [20/100], Loss: 445597.7812, time taken: 11.38 seconds
# Epoch [21/100]
# Epoch [21/100] and batch [1/3]
# Epoch [21/100] and batch [2/3]
# Epoch [21/100] and batch [3/3]
# Epoch [21/100], Loss: 389893.1250, time taken: 12.21 seconds
# Epoch [22/100]
# Epoch [22/100] and batch [1/3]
# Epoch [22/100] and batch [2/3]
# Epoch [22/100] and batch [3/3]
# Epoch [22/100], Loss: 341234.9062, time taken: 10.78 seconds
# Epoch [23/100]
# Epoch [23/100] and batch [1/3]
# Epoch [23/100] and batch [2/3]
# Epoch [23/100] and batch [3/3]
# Epoch [23/100], Loss: 296805.2812, time taken: 9.51 seconds
# Epoch [24/100]
# Epoch [24/100] and batch [1/3]
# Epoch [24/100] and batch [2/3]
# Epoch [24/100] and batch [3/3]
# Epoch [24/100], Loss: 256990.2500, time taken: 11.88 seconds
# Epoch [25/100]
# Epoch [25/100] and batch [1/3]
# Epoch [25/100] and batch [2/3]
# Epoch [25/100] and batch [3/3]
# Epoch [25/100], Loss: 222376.5156, time taken: 10.50 seconds
# Epoch [26/100]
# Epoch [26/100] and batch [1/3]
# Epoch [26/100] and batch [2/3]
# Epoch [26/100] and batch [3/3]
# Epoch [26/100], Loss: 192677.3281, time taken: 11.41 seconds
# Epoch [27/100]
# Epoch [27/100] and batch [1/3]
# Epoch [27/100] and batch [2/3]
# Epoch [27/100] and batch [3/3]
# Epoch [27/100], Loss: 166535.8906, time taken: 11.82 seconds
# Epoch [28/100]
# Epoch [28/100] and batch [1/3]
# Epoch [28/100] and batch [2/3]
# Epoch [28/100] and batch [3/3]
# Epoch [28/100], Loss: 142342.2969, time taken: 12.98 seconds
# Epoch [29/100]
# Epoch [29/100] and batch [1/3]
# Epoch [29/100] and batch [2/3]
# Epoch [29/100] and batch [3/3]
# Epoch [29/100], Loss: 121192.3203, time taken: 14.54 seconds
# Epoch [30/100]
# Epoch [30/100] and batch [1/3]
# Epoch [30/100] and batch [2/3]
# Epoch [30/100] and batch [3/3]
# Epoch [30/100], Loss: 104344.1328, time taken: 12.15 seconds
# Epoch [31/100]
# Epoch [31/100] and batch [1/3]
# Epoch [31/100] and batch [2/3]
# Epoch [31/100] and batch [3/3]
# Epoch [31/100], Loss: 88847.3594, time taken: 10.48 seconds
# Epoch [32/100]
# Epoch [32/100] and batch [1/3]
# Epoch [32/100] and batch [2/3]
# Epoch [32/100] and batch [3/3]
# Epoch [32/100], Loss: 73945.4922, time taken: 10.42 seconds
# Epoch [33/100]
# Epoch [33/100] and batch [1/3]
# Epoch [33/100] and batch [2/3]
# Epoch [33/100] and batch [3/3]
# Epoch [33/100], Loss: 63180.6484, time taken: 10.57 seconds
# Epoch [34/100]
# Epoch [34/100] and batch [1/3]
# Epoch [34/100] and batch [2/3]
# Epoch [34/100] and batch [3/3]
# Epoch [34/100], Loss: 54068.1602, time taken: 10.79 seconds
# Epoch [35/100]
# Epoch [35/100] and batch [1/3]
# Epoch [35/100] and batch [2/3]
# Epoch [35/100] and batch [3/3]
# Epoch [35/100], Loss: 44749.8672, time taken: 14.09 seconds
# Epoch [36/100]
# Epoch [36/100] and batch [1/3]
# Epoch [36/100] and batch [2/3]
# Epoch [36/100] and batch [3/3]
# Epoch [36/100], Loss: 37766.2773, time taken: 12.76 seconds
# Epoch [37/100]
# Epoch [37/100] and batch [1/3]
# Epoch [37/100] and batch [2/3]
# Epoch [37/100] and batch [3/3]
# Epoch [37/100], Loss: 32012.9219, time taken: 12.93 seconds
# Epoch [38/100]
# Epoch [38/100] and batch [1/3]
# Epoch [38/100] and batch [2/3]
# Epoch [38/100] and batch [3/3]
# Epoch [38/100], Loss: 26686.8105, time taken: 12.41 seconds
# Epoch [39/100]
# Epoch [39/100] and batch [1/3]
# Epoch [39/100] and batch [2/3]
# Epoch [39/100] and batch [3/3]
# Epoch [39/100], Loss: 22595.5645, time taken: 12.22 seconds
# Epoch [40/100]
# Epoch [40/100] and batch [1/3]
# Epoch [40/100] and batch [2/3]
# Epoch [40/100] and batch [3/3]
# Epoch [40/100], Loss: 18988.9102, time taken: 11.25 seconds
# Epoch [41/100]
# Epoch [41/100] and batch [1/3]
# Epoch [41/100] and batch [2/3]
# Epoch [41/100] and batch [3/3]
# Epoch [41/100], Loss: 15871.5635, time taken: 11.43 seconds
# Epoch [42/100]
# Epoch [42/100] and batch [1/3]
# Epoch [42/100] and batch [2/3]
# Epoch [42/100] and batch [3/3]
# Epoch [42/100], Loss: 13525.9121, time taken: 10.77 seconds
# Epoch [43/100]
# Epoch [43/100] and batch [1/3]
# Epoch [43/100] and batch [2/3]
# Epoch [43/100] and batch [3/3]
# Epoch [43/100], Loss: 11492.4766, time taken: 11.39 seconds
# Epoch [44/100]
# Epoch [44/100] and batch [1/3]
# Epoch [44/100] and batch [2/3]
# Epoch [44/100] and batch [3/3]
# Epoch [44/100], Loss: 10152.1914, time taken: 15.89 seconds
# Epoch [45/100]
# Epoch [45/100] and batch [1/3]
# Epoch [45/100] and batch [2/3]
# Epoch [45/100] and batch [3/3]
# Epoch [45/100], Loss: 8337.3262, time taken: 12.45 seconds
# Epoch [46/100]
# Epoch [46/100] and batch [1/3]
# Epoch [46/100] and batch [2/3]
# Epoch [46/100] and batch [3/3]
# Epoch [46/100], Loss: 7573.3081, time taken: 12.05 seconds
# Epoch [47/100]
# Epoch [47/100] and batch [1/3]
# Epoch [47/100] and batch [2/3]
# Epoch [47/100] and batch [3/3]
# Epoch [47/100], Loss: 6621.1763, time taken: 10.73 seconds
# Epoch [48/100]
# Epoch [48/100] and batch [1/3]
# Epoch [48/100] and batch [2/3]
# Epoch [48/100] and batch [3/3]
# Epoch [48/100], Loss: 5880.2197, time taken: 9.78 seconds
# Epoch [49/100]
# Epoch [49/100] and batch [1/3]
# Epoch [49/100] and batch [2/3]
# Epoch [49/100] and batch [3/3]
# Epoch [49/100], Loss: 5515.9341, time taken: 10.45 seconds
# Epoch [50/100]
# Epoch [50/100] and batch [1/3]
# Epoch [50/100] and batch [2/3]
# Epoch [50/100] and batch [3/3]
# Epoch [50/100], Loss: 5096.1958, time taken: 14.03 seconds
# Epoch [51/100]
# Epoch [51/100] and batch [1/3]
# Epoch [51/100] and batch [2/3]
# Epoch [51/100] and batch [3/3]
# Epoch [51/100], Loss: 4630.0361, time taken: 13.30 seconds
# Epoch [52/100]
# Epoch [52/100] and batch [1/3]
# Epoch [52/100] and batch [2/3]
# Epoch [52/100] and batch [3/3]
# Epoch [52/100], Loss: 4430.1025, time taken: 10.99 seconds
# Epoch [53/100]
# Epoch [53/100] and batch [1/3]
# Epoch [53/100] and batch [2/3]
# Epoch [53/100] and batch [3/3]
# Epoch [53/100], Loss: 4275.9141, time taken: 11.85 seconds
# Epoch [54/100]
# Epoch [54/100] and batch [1/3]
# Epoch [54/100] and batch [2/3]
# Epoch [54/100] and batch [3/3]
# Epoch [54/100], Loss: 4082.7568, time taken: 10.05 seconds
# Epoch [55/100]
# Epoch [55/100] and batch [1/3]
# Epoch [55/100] and batch [2/3]
# Epoch [55/100] and batch [3/3]
# Epoch [55/100], Loss: 3967.8503, time taken: 9.89 seconds
# Epoch [56/100]
# Epoch [56/100] and batch [1/3]
# Epoch [56/100] and batch [2/3]
# Epoch [56/100] and batch [3/3]
# Epoch [56/100], Loss: 3800.7380, time taken: 11.61 seconds
# Epoch [57/100]
# Epoch [57/100] and batch [1/3]
# Epoch [57/100] and batch [2/3]
# Epoch [57/100] and batch [3/3]
# Epoch [57/100], Loss: 3796.1196, time taken: 9.52 seconds
# Epoch [58/100]
# Epoch [58/100] and batch [1/3]
# Epoch [58/100] and batch [2/3]
# Epoch [58/100] and batch [3/3]
# Epoch [58/100], Loss: 3744.8616, time taken: 9.37 seconds
# Epoch [59/100]
# Epoch [59/100] and batch [1/3]
# Epoch [59/100] and batch [2/3]
# Epoch [59/100] and batch [3/3]
# Epoch [59/100], Loss: 3652.1697, time taken: 9.49 seconds
# Epoch [60/100]
# Epoch [60/100] and batch [1/3]
# Epoch [60/100] and batch [2/3]
# Epoch [60/100] and batch [3/3]
# Epoch [60/100], Loss: 3640.6262, time taken: 9.39 seconds
# Epoch [61/100]
# Epoch [61/100] and batch [1/3]
# Epoch [61/100] and batch [2/3]
# Epoch [61/100] and batch [3/3]
# Epoch [61/100], Loss: 3642.5327, time taken: 9.51 seconds
# Epoch [62/100]
# Epoch [62/100] and batch [1/3]
# Epoch [62/100] and batch [2/3]
# Epoch [62/100] and batch [3/3]
# Epoch [62/100], Loss: 3682.7183, time taken: 9.55 seconds
# Epoch [63/100]
# Epoch [63/100] and batch [1/3]
# Epoch [63/100] and batch [2/3]
# Epoch [63/100] and batch [3/3]
# Epoch [63/100], Loss: 3623.2510, time taken: 9.27 seconds
# Epoch [64/100]
# Epoch [64/100] and batch [1/3]
# Epoch [64/100] and batch [2/3]
# Epoch [64/100] and batch [3/3]
# Epoch [64/100], Loss: 3702.2737, time taken: 9.15 seconds
# Epoch [65/100]
# Epoch [65/100] and batch [1/3]
# Epoch [65/100] and batch [2/3]
# Epoch [65/100] and batch [3/3]
# Epoch [65/100], Loss: 3643.8557, time taken: 9.31 seconds
# Epoch [66/100]
# Epoch [66/100] and batch [1/3]
# Epoch [66/100] and batch [2/3]
# Epoch [66/100] and batch [3/3]
# Epoch [66/100], Loss: 3584.4341, time taken: 9.99 seconds
# Epoch [67/100]
# Epoch [67/100] and batch [1/3]
# Epoch [67/100] and batch [2/3]
# Epoch [67/100] and batch [3/3]
# Epoch [67/100], Loss: 3618.2520, time taken: 9.34 seconds
# Epoch [68/100]
# Epoch [68/100] and batch [1/3]
# Epoch [68/100] and batch [2/3]
# Epoch [68/100] and batch [3/3]
# Epoch [68/100], Loss: 3678.6987, time taken: 9.50 seconds
# Epoch [69/100]
# Epoch [69/100] and batch [1/3]
# Epoch [69/100] and batch [2/3]
# Epoch [69/100] and batch [3/3]
# Epoch [69/100], Loss: 3536.8823, time taken: 9.52 seconds
# Epoch [70/100]
# Epoch [70/100] and batch [1/3]
# Epoch [70/100] and batch [2/3]
# Epoch [70/100] and batch [3/3]
# Epoch [70/100], Loss: 3673.6438, time taken: 9.37 seconds
# Epoch [71/100]
# Epoch [71/100] and batch [1/3]
# Epoch [71/100] and batch [2/3]
# Epoch [71/100] and batch [3/3]
# Epoch [71/100], Loss: 3639.3030, time taken: 9.44 seconds
# Epoch [72/100]
# Epoch [72/100] and batch [1/3]
# Epoch [72/100] and batch [2/3]
# Epoch [72/100] and batch [3/3]
# Epoch [72/100], Loss: 3709.8674, time taken: 9.42 seconds
# Epoch [73/100]
# Epoch [73/100] and batch [1/3]
# Epoch [73/100] and batch [2/3]
# Epoch [73/100] and batch [3/3]
# Epoch [73/100], Loss: 3633.6309, time taken: 9.20 seconds
# Epoch [74/100]
# Epoch [74/100] and batch [1/3]
# Epoch [74/100] and batch [2/3]
# Epoch [74/100] and batch [3/3]
# Epoch [74/100], Loss: 3623.0479, time taken: 9.80 seconds
# Epoch [75/100]
# Epoch [75/100] and batch [1/3]
# Epoch [75/100] and batch [2/3]
# Epoch [75/100] and batch [3/3]
# Epoch [75/100], Loss: 3569.6660, time taken: 9.20 seconds
# Epoch [76/100]
# Epoch [76/100] and batch [1/3]
# Epoch [76/100] and batch [2/3]
# Epoch [76/100] and batch [3/3]
# Epoch [76/100], Loss: 3670.0742, time taken: 9.11 seconds
# Epoch [77/100]
# Epoch [77/100] and batch [1/3]
# Epoch [77/100] and batch [2/3]
# Epoch [77/100] and batch [3/3]
# Epoch [77/100], Loss: 3526.0796, time taken: 9.88 seconds
# Epoch [78/100]
# Epoch [78/100] and batch [1/3]
# Epoch [78/100] and batch [2/3]
# Epoch [78/100] and batch [3/3]
# Epoch [78/100], Loss: 3620.4641, time taken: 9.39 seconds
# Epoch [79/100]
# Epoch [79/100] and batch [1/3]
# Epoch [79/100] and batch [2/3]
# Epoch [79/100] and batch [3/3]
# Epoch [79/100], Loss: 3613.9299, time taken: 9.87 seconds
# Epoch [80/100]
# Epoch [80/100] and batch [1/3]
# Epoch [80/100] and batch [2/3]
# Epoch [80/100] and batch [3/3]
# Epoch [80/100], Loss: 3596.2563, time taken: 10.68 seconds
# Epoch [81/100]
# Epoch [81/100] and batch [1/3]
# Epoch [81/100] and batch [2/3]
# Epoch [81/100] and batch [3/3]
# Epoch [81/100], Loss: 3661.9519, time taken: 9.42 seconds
# Epoch [82/100]
# Epoch [82/100] and batch [1/3]
# Epoch [82/100] and batch [2/3]
# Epoch [82/100] and batch [3/3]
# Epoch [82/100], Loss: 3563.1626, time taken: 9.66 seconds
# Epoch [83/100]
# Epoch [83/100] and batch [1/3]
# Epoch [83/100] and batch [2/3]
# Epoch [83/100] and batch [3/3]
# Epoch [83/100], Loss: 3509.0579, time taken: 9.20 seconds
# Epoch [84/100]
# Epoch [84/100] and batch [1/3]
# Epoch [84/100] and batch [2/3]
# Epoch [84/100] and batch [3/3]
# Epoch [84/100], Loss: 3579.2361, time taken: 9.18 seconds
# Epoch [85/100]
# Epoch [85/100] and batch [1/3]
# Epoch [85/100] and batch [2/3]
# ...
# Processing i =  902  out of  1344
# Processing i =  903  out of  1344
# Processing i =  904  out of  1344
# Processing i =  905  out of  1344
# Processing i =  906  out of  1344
# Processing i =  907  out of  1344
# Processing i =  908  out of  1344
# Processing i =  909  out of  1344
# Processing i =  910  out of  1344
# Processing i =  911  out of  1344
# Processing i =  912  out of  1344
# Processing i =  913  out of  1344
# Processing i =  914  out of  1344
# Processing i =  915  out of  1344
# Processing i =  916  out of  1344
# Processing i =  917  out of  1344
# Processing i =  918  out of  1344
# Processing i =  919  out of  1344
# Processing i =  920  out of  1344
# Processing i =  921  out of  1344
# Processing i =  922  out of  1344
# Processing i =  923  out of  1344
# Processing i =  924  out of  1344
# Processing i =  925  out of  1344
# Processing i =  926  out of  1344
# Processing i =  927  out of  1344
# Processing i =  928  out of  1344
# Processing i =  929  out of  1344
# Processing i =  930  out of  1344
# Processing i =  931  out of  1344
# Processing i =  932  out of  1344
# Processing i =  933  out of  1344
# Processing i =  934  out of  1344
# Processing i =  935  out of  1344
# Processing i =  936  out of  1344
# Processing i =  937  out of  1344
# Processing i =  938  out of  1344
# Processing i =  939  out of  1344
# Processing i =  940  out of  1344
# Processing i =  941  out of  1344
# Processing i =  942  out of  1344
# Processing i =  943  out of  1344
# Processing i =  944  out of  1344
# Processing i =  945  out of  1344
# Processing i =  946  out of  1344
# Processing i =  947  out of  1344
# Processing i =  948  out of  1344
# Processing i =  949  out of  1344
# Processing i =  950  out of  1344
# Processing i =  951  out of  1344
# Processing i =  952  out of  1344
# Processing i =  953  out of  1344
# Processing i =  954  out of  1344
# Processing i =  955  out of  1344
# Processing i =  956  out of  1344
# Processing i =  957  out of  1344
# Processing i =  958  out of  1344
# Processing i =  959  out of  1344
# Processing i =  960  out of  1344
# Processing i =  961  out of  1344
# Processing i =  962  out of  1344
# Processing i =  963  out of  1344
# Processing i =  964  out of  1344
# Processing i =  965  out of  1344
# Processing i =  966  out of  1344
# Processing i =  967  out of  1344
# Processing i =  968  out of  1344
# Processing i =  969  out of  1344
# Processing i =  970  out of  1344
# Processing i =  971  out of  1344
# Processing i =  972  out of  1344
# Processing i =  973  out of  1344
# Processing i =  974  out of  1344
# Processing i =  975  out of  1344
# Processing i =  976  out of  1344
# Processing i =  977  out of  1344
# Processing i =  978  out of  1344
# Processing i =  979  out of  1344
# Processing i =  980  out of  1344
# Processing i =  981  out of  1344
# Processing i =  982  out of  1344
# Processing i =  983  out of  1344
# Processing i =  984  out of  1344
# Processing i =  985  out of  1344
# Processing i =  986  out of  1344
# Processing i =  987  out of  1344
# Processing i =  988  out of  1344
# Processing i =  989  out of  1344
# Processing i =  990  out of  1344
# Processing i =  991  out of  1344
# Processing i =  992  out of  1344
# Processing i =  993  out of  1344
# Processing i =  994  out of  1344
# Processing i =  995  out of  1344
# Processing i =  996  out of  1344
# Processing i =  997  out of  1344
# Processing i =  998  out of  1344
# Processing i =  999  out of  1344
# Processing i =  1000  out of  1344
# Processing i =  1001  out of  1344
# Processing i =  1002  out of  1344
# Processing i =  1003  out of  1344
# Processing i =  1004  out of  1344
# Processing i =  1005  out of  1344
# Processing i =  1006  out of  1344
# Processing i =  1007  out of  1344
# Processing i =  1008  out of  1344
# Processing i =  1009  out of  1344
# Processing i =  1010  out of  1344
# Processing i =  1011  out of  1344
# Processing i =  1012  out of  1344
# Processing i =  1013  out of  1344
# Processing i =  1014  out of  1344
# Processing i =  1015  out of  1344
# Processing i =  1016  out of  1344
# Processing i =  1017  out of  1344
# Processing i =  1018  out of  1344
# Processing i =  1019  out of  1344
# Processing i =  1020  out of  1344
# Processing i =  1021  out of  1344
# Processing i =  1022  out of  1344
# Processing i =  1023  out of  1344
# Processing i =  1024  out of  1344
# Processing i =  1025  out of  1344
# Processing i =  1026  out of  1344
# Processing i =  1027  out of  1344
# Processing i =  1028  out of  1344
# Processing i =  1029  out of  1344
# Processing i =  1030  out of  1344
# Processing i =  1031  out of  1344
# Processing i =  1032  out of  1344
# Processing i =  1033  out of  1344
# Processing i =  1034  out of  1344
# Processing i =  1035  out of  1344
# Processing i =  1036  out of  1344
# Processing i =  1037  out of  1344
# Processing i =  1038  out of  1344
# Processing i =  1039  out of  1344
# Processing i =  1040  out of  1344
# Processing i =  1041  out of  1344
# Processing i =  1042  out of  1344
# Processing i =  1043  out of  1344
# Processing i =  1044  out of  1344
# Processing i =  1045  out of  1344
# Processing i =  1046  out of  1344
# Processing i =  1047  out of  1344
# Processing i =  1048  out of  1344
# Processing i =  1049  out of  1344
# Processing i =  1050  out of  1344
# Processing i =  1051  out of  1344
# Processing i =  1052  out of  1344
# Processing i =  1053  out of  1344
# Processing i =  1054  out of  1344
# Processing i =  1055  out of  1344
# Processing i =  1056  out of  1344
# Processing i =  1057  out of  1344
# Processing i =  1058  out of  1344
# Processing i =  1059  out of  1344
# Processing i =  1060  out of  1344
# Processing i =  1061  out of  1344
# Processing i =  1062  out of  1344
# Processing i =  1063  out of  1344
# Processing i =  1064  out of  1344
# Processing i =  1065  out of  1344
# Processing i =  1066  out of  1344
# Processing i =  1067  out of  1344
# Processing i =  1068  out of  1344
# Processing i =  1069  out of  1344
# Processing i =  1070  out of  1344
# Processing i =  1071  out of  1344
# Processing i =  1072  out of  1344
# Processing i =  1073  out of  1344
# Processing i =  1074  out of  1344
# Processing i =  1075  out of  1344
# Processing i =  1076  out of  1344
# Processing i =  1077  out of  1344
# Processing i =  1078  out of  1344
# Processing i =  1079  out of  1344
# Processing i =  1080  out of  1344
# Processing i =  1081  out of  1344
# Processing i =  1082  out of  1344
# Processing i =  1083  out of  1344
# Processing i =  1084  out of  1344
# Processing i =  1085  out of  1344
# Processing i =  1086  out of  1344
# Processing i =  1087  out of  1344
# Processing i =  1088  out of  1344
# Processing i =  1089  out of  1344
# Processing i =  1090  out of  1344
# Processing i =  1091  out of  1344
# Processing i =  1092  out of  1344
# Processing i =  1093  out of  1344
# Processing i =  1094  out of  1344
# Processing i =  1095  out of  1344
# Processing i =  1096  out of  1344
# Processing i =  1097  out of  1344
# Processing i =  1098  out of  1344
# Processing i =  1099  out of  1344
# Processing i =  1100  out of  1344
# Processing i =  1101  out of  1344
# Processing i =  1102  out of  1344
# Processing i =  1103  out of  1344
# Processing i =  1104  out of  1344
# Processing i =  1105  out of  1344
# Processing i =  1106  out of  1344
# Processing i =  1107  out of  1344
# Processing i =  1108  out of  1344
# Processing i =  1109  out of  1344
# Processing i =  1110  out of  1344
# Processing i =  1111  out of  1344
# Processing i =  1112  out of  1344
# Processing i =  1113  out of  1344
# Processing i =  1114  out of  1344
# Processing i =  1115  out of  1344
# Processing i =  1116  out of  1344
# Processing i =  1117  out of  1344
# Processing i =  1118  out of  1344
# Processing i =  1119  out of  1344
# Processing i =  1120  out of  1344
# Processing i =  1121  out of  1344
# Processing i =  1122  out of  1344
# Processing i =  1123  out of  1344
# Processing i =  1124  out of  1344
# Processing i =  1125  out of  1344
# Processing i =  1126  out of  1344
# Processing i =  1127  out of  1344
# Processing i =  1128  out of  1344
# Processing i =  1129  out of  1344
# Processing i =  1130  out of  1344
# Processing i =  1131  out of  1344
# Processing i =  1132  out of  1344
# Processing i =  1133  out of  1344
# Processing i =  1134  out of  1344
# Processing i =  1135  out of  1344
# Processing i =  1136  out of  1344
# Processing i =  1137  out of  1344
# Processing i =  1138  out of  1344
# Processing i =  1139  out of  1344
# Processing i =  1140  out of  1344
# Processing i =  1141  out of  1344
# Processing i =  1142  out of  1344
# Processing i =  1143  out of  1344
# Processing i =  1144  out of  1344
# Processing i =  1145  out of  1344
# Processing i =  1146  out of  1344
# Processing i =  1147  out of  1344
# Processing i =  1148  out of  1344
# Processing i =  1149  out of  1344
# Processing i =  1150  out of  1344
# Processing i =  1151  out of  1344
# Processing i =  1152  out of  1344
# Processing i =  1153  out of  1344
# Processing i =  1154  out of  1344
# Processing i =  1155  out of  1344
# Processing i =  1156  out of  1344
# Processing i =  1157  out of  1344
# Processing i =  1158  out of  1344
# Processing i =  1159  out of  1344
# Processing i =  1160  out of  1344
# Processing i =  1161  out of  1344
# Processing i =  1162  out of  1344
# Processing i =  1163  out of  1344
# Processing i =  1164  out of  1344
# Processing i =  1165  out of  1344
# Processing i =  1166  out of  1344
# Processing i =  1167  out of  1344
# Processing i =  1168  out of  1344
# Processing i =  1169  out of  1344
# Processing i =  1170  out of  1344
# Processing i =  1171  out of  1344
# Processing i =  1172  out of  1344
# Processing i =  1173  out of  1344
# Processing i =  1174  out of  1344
# Processing i =  1175  out of  1344
# Processing i =  1176  out of  1344
# Processing i =  1177  out of  1344
# Processing i =  1178  out of  1344
# Processing i =  1179  out of  1344
# Processing i =  1180  out of  1344
# Processing i =  1181  out of  1344
# Processing i =  1182  out of  1344
# Processing i =  1183  out of  1344
# Processing i =  1184  out of  1344
# Processing i =  1185  out of  1344
# Processing i =  1186  out of  1344
# Processing i =  1187  out of  1344
# Processing i =  1188  out of  1344
# Processing i =  1189  out of  1344
# Processing i =  1190  out of  1344
# Processing i =  1191  out of  1344
# Processing i =  1192  out of  1344
# Processing i =  1193  out of  1344
# Processing i =  1194  out of  1344
# Processing i =  1195  out of  1344
# Processing i =  1196  out of  1344
# Processing i =  1197  out of  1344
# Processing i =  1198  out of  1344
# Processing i =  1199  out of  1344
# Processing i =  1200  out of  1344
# Processing i =  1201  out of  1344
# Processing i =  1202  out of  1344
# Processing i =  1203  out of  1344
# Processing i =  1204  out of  1344
# Processing i =  1205  out of  1344
# Processing i =  1206  out of  1344
# Processing i =  1207  out of  1344
# Processing i =  1208  out of  1344
# Processing i =  1209  out of  1344
# Processing i =  1210  out of  1344
# Processing i =  1211  out of  1344
# Processing i =  1212  out of  1344
# Processing i =  1213  out of  1344
# Processing i =  1214  out of  1344
# Processing i =  1215  out of  1344
# Processing i =  1216  out of  1344
# Processing i =  1217  out of  1344
# Processing i =  1218  out of  1344
# Processing i =  1219  out of  1344
# Processing i =  1220  out of  1344
# Processing i =  1221  out of  1344
# Processing i =  1222  out of  1344
# Processing i =  1223  out of  1344
# Processing i =  1224  out of  1344
# Processing i =  1225  out of  1344
# Processing i =  1226  out of  1344
# Processing i =  1227  out of  1344
# Processing i =  1228  out of  1344
# Processing i =  1229  out of  1344
# Processing i =  1230  out of  1344
# Processing i =  1231  out of  1344
# Processing i =  1232  out of  1344
# Processing i =  1233  out of  1344
# Processing i =  1234  out of  1344
# Processing i =  1235  out of  1344
# Processing i =  1236  out of  1344
# Processing i =  1237  out of  1344
# Processing i =  1238  out of  1344
# Processing i =  1239  out of  1344
# Processing i =  1240  out of  1344
# Processing i =  1241  out of  1344
# Processing i =  1242  out of  1344
# Processing i =  1243  out of  1344
# Processing i =  1244  out of  1344
# Processing i =  1245  out of  1344
# Processing i =  1246  out of  1344
# Processing i =  1247  out of  1344
# Processing i =  1248  out of  1344
# Processing i =  1249  out of  1344
# Processing i =  1250  out of  1344
# Processing i =  1251  out of  1344
# Processing i =  1252  out of  1344
# Processing i =  1253  out of  1344
# Processing i =  1254  out of  1344
# Processing i =  1255  out of  1344
# Processing i =  1256  out of  1344
# Processing i =  1257  out of  1344
# Processing i =  1258  out of  1344
# Processing i =  1259  out of  1344
# Processing i =  1260  out of  1344
# Processing i =  1261  out of  1344
# Processing i =  1262  out of  1344
# Processing i =  1263  out of  1344
# Processing i =  1264  out of  1344
# Processing i =  1265  out of  1344
# Processing i =  1266  out of  1344
# Processing i =  1267  out of  1344
# Processing i =  1268  out of  1344
# Processing i =  1269  out of  1344
# Processing i =  1270  out of  1344
# Processing i =  1271  out of  1344
# Processing i =  1272  out of  1344
# Processing i =  1273  out of  1344
# Processing i =  1274  out of  1344
# Processing i =  1275  out of  1344
# Processing i =  1276  out of  1344
# Processing i =  1277  out of  1344
# Processing i =  1278  out of  1344
# Processing i =  1279  out of  1344
# Processing i =  1280  out of  1344
# Processing i =  1281  out of  1344
# Processing i =  1282  out of  1344
# Processing i =  1283  out of  1344
# Processing i =  1284  out of  1344
# Processing i =  1285  out of  1344
# Processing i =  1286  out of  1344
# Processing i =  1287  out of  1344
# Processing i =  1288  out of  1344
# Processing i =  1289  out of  1344
# Processing i =  1290  out of  1344
# Processing i =  1291  out of  1344
# Processing i =  1292  out of  1344
# Processing i =  1293  out of  1344
# Processing i =  1294  out of  1344
# Processing i =  1295  out of  1344
# Processing i =  1296  out of  1344
# Processing i =  1297  out of  1344
# Processing i =  1298  out of  1344
# Processing i =  1299  out of  1344
# Processing i =  1300  out of  1344
# Processing i =  1301  out of  1344
# Processing i =  1302  out of  1344
# Processing i =  1303  out of  1344
# Processing i =  1304  out of  1344
# Processing i =  1305  out of  1344
# Processing i =  1306  out of  1344
# Processing i =  1307  out of  1344
# Processing i =  1308  out of  1344
# Processing i =  1309  out of  1344
# Processing i =  1310  out of  1344
# Processing i =  1311  out of  1344
# Processing i =  1312  out of  1344
# Processing i =  1313  out of  1344
# Processing i =  1314  out of  1344
# Processing i =  1315  out of  1344
# Processing i =  1316  out of  1344
# Processing i =  1317  out of  1344
# Processing i =  1318  out of  1344
# Processing i =  1319  out of  1344
# Processing i =  1320  out of  1344
# Processing i =  1321  out of  1344
# Processing i =  1322  out of  1344
# Processing i =  1323  out of  1344
# Processing i =  1324  out of  1344
# Processing i =  1325  out of  1344
# Processing i =  1326  out of  1344
# Processing i =  1327  out of  1344
# Processing i =  1328  out of  1344
# Processing i =  1329  out of  1344
# Processing i =  1330  out of  1344
# Processing i =  1331  out of  1344
# Processing i =  1332  out of  1344
# Processing i =  1333  out of  1344
# Processing i =  1334  out of  1344
# Processing i =  1335  out of  1344
# Processing i =  1336  out of  1344
# Processing i =  1337  out of  1344
# Processing i =  1338  out of  1344
# Processing i =  1339  out of  1344
# Processing i =  1340  out of  1344
# Processing i =  1341  out of  1344
# Processing i =  1342  out of  1344
# Processing i =  1343  out of  1344
# Processing i =  1344  out of  1344
#
# Processing CV 10 / 10....
# Test set is before train set / CV 10, no test forecast can be made
#
# [PyNNLF recap] WARNING: no result file in C:\Users\z5404477\Documents\PyNNLF\publication\journal_article_1\experiment_result\E00009_260501_ds16_fh30_m13_lstm_hp2
# [PyNNLF recap] WARNING: no result file in C:\Users\z5404477\Documents\PyNNLF\publication\journal_article_1\experiment_result\E00010_260501_ds16_fh30_m13_lstm_hp2
# Full SA BESS batch complete. Recap: C:\Users\z5404477\Documents\PyNNLF\publication\journal_article_1\experiment_result\a1_experiment_result.csv

# %% [markdown]
# ## 4. Inspect Recap
#
# After the batch finishes, inspect the PyNNLF recap. The complete SA BESS run should have 36 rows: 3 datasets by 12 model/hyperparameter choices.

# %%
recap_path = PROJECT_DIR / 'experiment_result' / 'a1_experiment_result.csv'
recap = pd.read_csv(recap_path)
print(f'Recap rows: {len(recap):,}')
display(recap[['dataset_no', 'model_name', 'test_nRMSE', 'test_nRMSE_stddev']])
# Out:
# Recap rows: 36
#    dataset_no       model_name  test_nRMSE  test_nRMSE_stddev
# 0        ds16      m17_xgb_hp1    3.224934           0.293571
# 1        ds16       m8_dnn_hp1    5.986006           0.703674
# 2        ds16        m6_lr_hp1    3.082543           0.228790
# 3        ds16       m10_rf_hp1    4.376197           0.339607
# 4        ds16       m7_ann_hp1    5.460705           0.601846
# 5        ds16     m1_naive_hp1    4.270692           0.244157
# 6        ds16       m3_ets_hp1    4.212272           0.168914
# 7        ds16        m9_rt_hp3    6.725240           0.815398
# 8        ds16     m13_lstm_hp2   16.774768           1.706541
# 9        ds16    m2_snaive_hp2    7.516114           1.249377
# 10       ds16  m16_prophet_hp1    6.851643           1.309192
# 11       ds16     m4_arima_hp1    3.970578           0.168664
# 12       ds17      m17_xgb_hp1    6.305710           0.930540
# 13       ds17       m8_dnn_hp1    9.267245           1.713207
# 14       ds17        m6_lr_hp1    5.769087           0.470714
# 15       ds17       m10_rf_hp1   12.655225           1.610819
# 16       ds17       m7_ann_hp1    9.129553           1.129429
# 17       ds17     m1_naive_hp1   11.497058           1.347774
# 18       ds17       m3_ets_hp1   11.336787           1.323548
# 19       ds17        m9_rt_hp3   18.195774           2.432907
# 20       ds17     m13_lstm_hp2   59.803457          10.808015
# 21       ds17    m2_snaive_hp2   22.470394           3.666507
# 22       ds17  m16_prophet_hp1   21.574314           5.507452
# 23       ds17     m4_arima_hp1    9.177585           0.853422
# 24       ds18      m17_xgb_hp1    5.571771           0.983519
# 25       ds18       m8_dnn_hp1    8.746302           1.735866
# 26       ds18        m6_lr_hp1    5.092104           0.466129
# 27       ds18       m10_rf_hp1   11.326524           1.612574
# 28       ds18       m7_ann_hp1    7.938964           1.150363
# 29       ds18     m1_naive_hp1    9.818598           1.832779
# 30       ds18       m3_ets_hp1    9.618823           1.823998
# 31       ds18        m9_rt_hp3   16.532020           2.389269
# 32       ds18     m13_lstm_hp2   51.616593          11.327788
# 33       ds18    m2_snaive_hp2   21.341975           4.083446
# 34       ds18  m16_prophet_hp1   20.546177           5.409208
# 35       ds18     m4_arima_hp1    7.913740           1.062988

# %% [markdown]
# ## 5. Build Publication Tables
#
# Create the two wide CSV tables for the article: one for test nRMSE and one for test nRMSE standard deviation.

# %%
from process_pynnlf_output import build_publication_tables

nrmse_table, nrmse_stddev_table = build_publication_tables(PROJECT_DIR)
display(nrmse_table)
display(nrmse_stddev_table)
print(PROJECT_DIR / 'results' / 'sa_bess_nrmse_comparison.csv')
print(PROJECT_DIR / 'results' / 'sa_bess_nrmse_stddev_comparison.csv')
# Out:
#                  underlying_load  net_load_with_pv  net_load_with_pv_battery
# model_hp
# m17_xgb_hp1             3.224934          6.305710                  5.571771
# m8_dnn_hp1              5.986006          9.267245                  8.746302
# m6_lr_hp1               3.082543          5.769087                  5.092104
# m10_rf_hp1              4.376197         12.655225                 11.326524
# m7_ann_hp1              5.460705          9.129553                  7.938964
# m1_naive_hp1            4.270692         11.497058                  9.818598
# m3_ets_hp1              4.212272         11.336787                  9.618823
# m9_rt_hp3               6.725240         18.195774                 16.532020
# m13_lstm_hp2           16.774768         59.803457                 51.616593
# m2_snaive_hp2           7.516114         22.470394                 21.341975
# m16_prophet_hp1         6.851643         21.574314                 20.546177
# m4_arima_hp1            3.970578          9.177585                  7.913740
#                  underlying_load  net_load_with_pv  net_load_with_pv_battery
# model_hp
# m17_xgb_hp1             0.293571          0.930540                  0.983519
# m8_dnn_hp1              0.703674          1.713207                  1.735866
# m6_lr_hp1               0.228790          0.470714                  0.466129
# m10_rf_hp1              0.339607          1.610819                  1.612574
# m7_ann_hp1              0.601846          1.129429                  1.150363
# m1_naive_hp1            0.244157          1.347774                  1.832779
# m3_ets_hp1              0.168914          1.323548                  1.823998
# m9_rt_hp3               0.815398          2.432907                  2.389269
# m13_lstm_hp2            1.706541         10.808015                 11.327788
# m2_snaive_hp2           1.249377          3.666507                  4.083446
# m16_prophet_hp1         1.309192          5.507452                  5.409208
# m4_arima_hp1            0.168664          0.853422                  1.062988
# C:\Users\z5404477\Documents\PyNNLF\publication\journal_article_1\results\sa_bess_nrmse_comparison.csv
# C:\Users\z5404477\Documents\PyNNLF\publication\journal_article_1\results\sa_bess_nrmse_stddev_comparison.csv

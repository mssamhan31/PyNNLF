# %% [markdown]
# # Build Final Figures (Section 01)
#
# ## Purpose
# Rebuilds final Ausgrid Solar Home Dataset (ASHD) vs Australia Energy Data Platform (AEDP) paper-facing figures from existing outputs only.
#
# ## Run Flow
# 1. Resolve project paths and import the shared build helper.
# 2. Validate required inputs.
# 3. Rebuild canonical Section 01 figures.
# 4. Validate expected Section 01 artifacts.
#
# ## Expected Section 01 Outputs
# - `results/01_ashd_aedp_148hh_comparison/figures/fig30_ashd_vs_aedp_xgb_actual_vs_forecast_daypair.png`
# - `results/01_ashd_aedp_148hh_comparison/figures/fig31_ashd_vs_aedp_xgb_error_profile_daypair.png`
# - `results/paper_artifact_output_check.csv` (validation report)
#
# ## Notes
# This notebook does not rerun model training; it rebuilds publication artifacts only.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = next((p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'publication' / 'journal_article_1').exists()), None)
if PROJECT_ROOT is None:
    raise RuntimeError('Could not resolve project root from current working directory.')

SCRIPTS_DIR = PROJECT_ROOT / 'publication' / 'journal_article_1' / 'scripts'
if str(SCRIPTS_DIR) not in sys.path:
    sys.path.insert(0, str(SCRIPTS_DIR))

import notebook_artifact_build as nab

# %%
section = '01'
print('=== Section 01: build figures ===')
expected = nab.list_expected_artifacts(section)
print(f'Expected canonical artifacts in section {section}: {len(expected)}')
for p in expected:
    print(' -', p)

nab.ensure_required_inputs()
outputs = nab.build_section_01()
print(f'Generated outputs: {len(outputs)}')
for p in outputs:
    print('generated', p)
# Out:
# === Section 01: build figures ===
# Expected canonical artifacts in section 01: 2
#  - results/01_ashd_aedp_148hh_comparison/figures/fig30_ashd_vs_aedp_xgb_actual_vs_forecast_daypair.png
#  - results/01_ashd_aedp_148hh_comparison/figures/fig31_ashd_vs_aedp_xgb_error_profile_daypair.png
# Generated outputs: 2
# generated <local path redacted>
# generated <local path redacted>

# %%
print('=== Section 01: validation ===')
check = nab.check_artifacts('01')
display(check)

exists_count = int(check['exists'].sum())
missing_count = len(check) - exists_count
print(f'Validation summary: {exists_count}/{len(check)} artifacts exist; missing={missing_count}')

if missing_count:
    print('Missing artifacts:')
    for p in check.loc[~check['exists'], 'path']:
        print(' -', p)

nab.assert_artifacts('01')
print('Section 01 artifact check passed.')
# Out:
# === Section 01: validation ===
#                                                 path  exists  size_bytes
# 0  results/01_ashd_aedp_148hh_comparison/figures/...    True      700703
# 1  results/01_ashd_aedp_148hh_comparison/figures/...    True      552445
# Validation summary: 2/2 artifacts exist; missing=0
# Section 01 artifact check passed.
